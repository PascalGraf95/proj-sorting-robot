# %% [markdown]
# # Description
# ### This Jupyter Notebook is part of the Projektwork 2023-24 in order to be able to make a quantized statement
# #### 32 Peaces in each type of seperator
# #### Multiple Runs
# #### Count the amount of individual objects

# %%
import cv2

# %%
# Imports
import cv2
import os
import matplotlib.pyplot as plt
from imutils.video import VideoStream
from imutils.video import FPS
import argparse
import imutils
import time

# %%
# Define Pathes
folder ='C:\\Users\\AI-Student\\Desktop\\VideoFiles\\Vereinzelung'
File1 ='C:\Users\AI-Student\Desktop\VideoFiles\Vereinzelung\Vereinzelung_Ruettler.avi'
File2 ='C:\Users\AI-Student\Desktop\VideoFiles\Vereinzelung\Vereinzelung_Ruettler_Gate.avi'
File3 ='C:\Users\AI-Student\Desktop\VideoFiles\Vereinzelung\Vereinzelung_Spirale.avi'

# %%
def DetectAmountObjekts(path):
    cap = cv2.VideoCapture(format(path))

    roi_x = 620
    roi_y = 200
    roi_width = 2
    roi_height = 740

    threshold = 150

    scan_area = [500, 220, 500, 700]

    object_detected = False
    total_objects = 0

    cv2.namedWindow('MainWindow', cv2.WINDOW_NORMAL)

    while True:
        ret, frame = cap.read()
        if not ret:
            break

        # Extrahieren Sie den Scannbereich und ROI aus dem Frame
        scan_roi = frame[scan_area[1]:scan_area[1] + scan_area[3], scan_area[0]:scan_area[0] + scan_area[2]].copy()
        roi = frame[roi_y:roi_y + roi_height, roi_x:roi_x + roi_width].copy()

        cv2.putText(frame, f"Left: {roi_x}", (roi_x, roi_y), cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 0, 255), 1)
        cv2.putText(frame, f"Right: {roi_x+roi_width}", (roi_x+roi_width, roi_y+roi_height), cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 0, 255), 1)

        # Konvertieren Sie das ROI in Graustufen
        roi_gray = cv2.cvtColor(scan_roi, cv2.COLOR_BGR2GRAY)

        # Binarisieren Sie das ROI
        _, binary_roi = cv2.threshold(roi_gray, threshold, 255, cv2.THRESH_BINARY)
        cv2.imshow('binary_roi', binary_roi)

        # Finden Sie Konturen im binarisierten ROI
        contours, _ = cv2.findContours(binary_roi, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
        nr =  0
        for cnt in contours:
            nr =nr+1
            M = cv2.moments(cnt)
            if M["m00"] != 0:
                cx = int(M["m10"] / M["m00"])
                cy = int(M["m01"] / M["m00"])

                # Berücksichtigen Sie den Versatz des ROI im Hauptbild
                cx += scan_area[0]
                cy += scan_area[1]

                cnt[:, 0, 0] += scan_area[0]
                cnt[:, 0, 1] += scan_area[1]

                cv2.putText(frame, f"cx: {cx}", (cx, cy), cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 0, 255), 1)
                #cv2.putText(frame, f"cy: {cy}", (cx, cy+20), cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 0, 255), 1)

                cv2.circle(frame, (cx,cy), radius=10, color=(0, 0, 255), thickness=-1)
                print("Contournr:{}".format(nr)+"cx:{}".format(cx))
                print("cy:{}".format(cy))

                # Überprüfen Sie, ob der Mittelpunkt innerhalb des Scannbereichs liegt
                #if roi_x <= cx <= roi_x + roi_width and roi_y <= cy <= roi_x + roi_height:
                if roi_x <= cx <= roi_x + roi_width:
                    if not object_detected:
                        total_objects += 1
                        #object_detected = True
                        print(f"Objekt {total_objects} im Scannbereich erkannt und gezählt!")

        if cv2.countNonZero(binary_roi) == 0:
            object_detected = False



        # Zeichnen Sie das Rechteck um den Scannbereich
        cv2.rectangle(frame, (scan_area[0], scan_area[1]), (scan_area[0] + scan_area[2], scan_area[1] + scan_area[3]), (0, 255, 0), 2)

        # Zeichnen Sie das Rechteck um den ROI
        cv2.rectangle(frame, (roi_x, roi_y), (roi_x + roi_width, roi_y + roi_height), (0, 0, 255), 2)

        # Zeigen Sie die Gesamtzahl der erkannten Objekte an
        cv2.putText(frame, f"Gesamtobjekte: {total_objects}", (10, 30), cv2.FONT_HERSHEY_SIMPLEX, 1, (255, 255, 255), 2)

        # Zeichnen Sie die Konturen der erkannten Objekte
        cv2.drawContours(frame, contours, -1, (0, 0, 255), 2)

        # Zeigen Sie das Hauptfenster
        cv2.imshow('MainWindow', frame)

        # Zeigen Sie den ROI
        cv2.imshow('ROI', roi)

        # Zeigen Sie das binarisierte Bild des Scannbereichs
        cv2.imshow('Scannbereich', scan_roi)

        key = cv2.waitKey(15) & 0xff
        # ESC to close
        if key == 27:
            break
        # Space for pause
        elif key == 32:
            cv2.waitKey() & 0xff

    cap.release()
    cv2.destroyAllWindows()

    return total_objects

# %%
Result = []
for file in os.listdir(folder):
    path = folder + '\\' + format(file)
    print(path)
    total_objects = DetectAmountObjekts(path)
    Result.append(total_objects)
# Out:
# C:\Users\AI-Student\Desktop\VideoFiles\Vereinzelung\Vereinzelung_Ruettler.avi
# Contournr:1cx:535
# cy:484
# Contournr:1cx:531
# cy:485
# Contournr:1cx:522
# cy:486
# Contournr:1cx:518
# cy:485
# Contournr:1cx:997
# cy:637
# Contournr:1cx:996
# cy:627
# Contournr:1cx:994
# cy:622
# Contournr:1cx:991
# cy:621
# Contournr:1cx:989
# cy:621
# Contournr:1cx:987
# cy:621
# Contournr:1cx:984
# cy:621
# Contournr:1cx:982
# cy:621
# Contournr:1cx:979
# cy:622
# Contournr:1cx:977
# cy:622
# Contournr:1cx:974
# cy:622
# Contournr:1cx:972
# cy:623
# Contournr:1cx:969
# cy:623
# Contournr:1cx:967
# cy:624
# Contournr:1cx:964
# cy:624
# Contournr:1cx:962
# cy:624
# Contournr:1cx:959
# cy:625
# Contournr:1cx:957
# cy:625
# Contournr:1cx:954
# cy:626
# Contournr:1cx:952
# cy:626
# Contournr:1cx:950
# cy:627
# Contournr:1cx:947
# cy:627
# Contournr:1cx:945
# cy:628
# Contournr:1cx:942
# cy:628
# Contournr:1cx:940
# cy:628
# Contournr:1cx:937
# cy:629
# Contournr:1cx:934
# cy:629
# Contournr:1cx:929
# cy:629
# Contournr:1cx:924
# cy:629
# Contournr:1cx:918
# cy:629
# Contournr:1cx:913
# cy:629
# Contournr:1cx:908
# cy:629
# Contournr:1cx:903
# cy:629
# Contournr:1cx:898
# cy:630
# Contournr:1cx:893
# cy:630
# Contournr:1cx:887
# cy:630
# Contournr:1cx:882
# cy:630
# Contournr:1cx:877
# cy:630
# Contournr:1cx:872
# cy:630
# Contournr:1cx:867
# cy:630
# Contournr:1cx:861
# cy:630
# Contournr:1cx:856
# cy:630
# Contournr:1cx:851
# cy:631
# Contournr:1cx:846
# cy:631
# Contournr:1cx:841
# cy:631
# Contournr:1cx:835
# cy:631
# Contournr:1cx:830
# cy:631
# Contournr:2cx:998
# cy:550
# Contournr:1cx:825
# cy:631
# Contournr:2cx:996
# cy:546
# Contournr:1cx:819
# cy:631
# Contournr:2cx:994
# cy:541
# Contournr:1cx:814
# cy:631
# Contournr:2cx:993
# cy:536
# Contournr:1cx:809
# cy:632
# Contournr:2cx:991
# cy:531
# Contournr:1cx:804
# cy:632
# Contournr:2cx:989
# cy:526
# Contournr:1cx:798
# cy:632
# Contournr:2cx:988
# cy:522
# Contournr:1cx:793
# cy:632
# Contournr:2cx:986
# cy:517
# Contournr:1cx:788
# cy:632
# Contournr:2cx:998
# cy:584
# Contournr:3cx:984
# cy:514
# Contournr:1cx:783
# cy:632
# Contournr:2cx:996
# cy:622
# Contournr:3cx:982
# cy:512
# Contournr:1cx:778
# cy:632
# Contournr:2cx:994
# cy:633
# Contournr:3cx:980
# cy:511
# Contournr:4cx:997
# cy:373
# Contournr:1cx:773
# cy:632
# Contournr:2cx:992
# cy:636
# Contournr:3cx:978
# cy:510
# Contournr:4cx:995
# cy:375
# Contournr:1cx:768
# cy:632
# Contournr:2cx:989
# cy:638
# Contournr:3cx:975
# cy:510
# Contournr:4cx:993
# cy:377
# Contournr:1cx:763
# cy:632
# Contournr:2cx:987
# cy:638
# Contournr:3cx:973
# cy:510
# Contournr:4cx:991
# cy:377
# Contournr:1cx:757
# cy:632
# Contournr:2cx:985
# cy:639
# Contournr:3cx:970
# cy:509
# Contournr:4cx:989
# cy:377
# Contournr:1cx:752
# cy:632
# Contournr:2cx:982
# cy:639
# Contournr:3cx:967
# cy:508
# Contournr:4cx:987
# cy:377
# Contournr:1cx:747
# cy:633
# Contournr:2cx:980
# cy:639
# Contournr:3cx:963
# cy:507
# Contournr:4cx:984
# cy:377
# Contournr:1cx:742
# cy:633
# Contournr:2cx:977
# cy:640
# Contournr:3cx:960
# cy:506
# Contournr:4cx:982
# cy:376
# Contournr:1cx:737
# cy:633
# Contournr:2cx:975
# cy:640
# Contournr:4cx:955
# cy:505
# Contournr:5cx:980
# cy:375
# Contournr:1cx:732
# cy:633
# Contournr:2cx:972
# cy:640
# Contournr:3cx:996
# cy:523
# Contournr:4cx:951
# cy:505
# Contournr:5cx:977
# cy:374
# Contournr:1cx:727
# cy:633
# Contournr:2cx:970
# cy:640
# Contournr:3cx:994
# cy:523
# Contournr:4cx:946
# cy:505
# Contournr:5cx:975
# cy:373
# Contournr:1cx:721
# cy:633
# Contournr:2cx:967
# cy:640
# Contournr:3cx:992
# cy:523
# Contournr:4cx:942
# cy:504
# Contournr:5cx:972
# cy:372
# Contournr:2cx:716
# cy:633
# Contournr:3cx:966
# cy:636
# Contournr:4cx:937
# cy:504
# Contournr:5cx:970
# cy:371
# Contournr:1cx:998
# cy:688
# Contournr:2cx:998
# cy:678
# Contournr:3cx:998
# cy:663
# Contournr:4cx:711
# cy:633
# Contournr:5cx:962
# cy:632
# Contournr:6cx:933
# cy:503
# Contournr:7cx:997
# cy:419
# Contournr:8cx:997
# cy:406
# Contournr:9cx:967
# cy:370
# Contournr:1cx:998
# cy:737
# Contournr:2cx:998
# cy:724
# Contournr:3cx:997
# cy:710
# Contournr:4cx:706
# cy:633
# Contournr:5cx:954
# cy:641
# Contournr:6cx:991
# cy:581
# Contournr:7cx:929
# cy:502
# Contournr:8cx:995
# cy:407
# Contournr:9cx:965
# cy:369
# Contournr:1cx:998
# cy:754
# Contournr:2cx:701
# cy:633
# Contournr:3cx:960
# cy:630
# Contournr:4cx:925
# cy:501
# Contournr:5cx:993
# cy:405
# Contournr:6cx:962
# cy:368
# Contournr:1cx:696
# cy:633
# Contournr:2cx:959
# cy:631
# Contournr:3cx:921
# cy:501
# Contournr:4cx:990
# cy:405
# Contournr:5cx:960
# cy:367
# Contournr:1cx:691
# cy:634
# Contournr:2cx:939
# cy:642
# Contournr:3cx:984
# cy:614
# Contournr:4cx:997
# cy:476
# Contournr:5cx:916
# cy:501
# Contournr:6cx:987
# cy:405
# Contournr:7cx:957
# cy:366
# Contournr:1cx:997
# cy:624
# Contournr:2cx:686
# cy:634
# Contournr:3cx:933
# cy:642
# Contournr:4cx:980
# cy:614
# Contournr:5cx:995
# cy:481
# Contournr:6cx:912
# cy:500
# Contournr:7cx:984
# cy:407
# Contournr:8cx:955
# cy:365
# Contournr:1cx:996
# cy:629
# Contournr:2cx:681
# cy:634
# Contournr:3cx:928
# cy:642
# Contournr:4cx:974
# cy:614
# Contournr:5cx:993
# cy:486
# Contournr:6cx:908
# cy:500
# Contournr:7cx:981
# cy:408
# Contournr:8cx:953
# cy:364
# Contournr:1cx:994
# cy:635
# Contournr:2cx:676
# cy:634
# Contournr:3cx:923
# cy:642
# Contournr:4cx:970
# cy:614
# Contournr:5cx:991
# cy:490
# Contournr:6cx:904
# cy:499
# Contournr:7cx:978
# cy:409
# Contournr:8cx:950
# cy:363
# Contournr:1cx:992
# cy:640
# Contournr:2cx:671
# cy:634
# Contournr:3cx:918
# cy:642
# Contournr:4cx:965
# cy:614
# Contournr:5cx:989
# cy:494
# Contournr:6cx:900
# cy:499
# Contournr:7cx:975
# cy:410
# Contournr:8cx:948
# cy:362
# Contournr:1cx:990
# cy:643
# Contournr:2cx:666
# cy:634
# Contournr:3cx:913
# cy:642
# Contournr:4cx:960
# cy:614
# Contournr:5cx:986
# cy:499
# Contournr:6cx:897
# cy:499
# Contournr:7cx:973
# cy:413
# Contournr:8cx:945
# cy:361
# Contournr:1cx:988
# cy:645
# Contournr:2cx:661
# cy:634
# Contournr:3cx:908
# cy:642
# Contournr:4cx:998
# cy:576
# Contournr:5cx:955
# cy:615
# Contournr:6cx:998
# cy:506
# Contournr:8cx:984
# cy:503
# Contournr:9cx:893
# cy:499
# Contournr:10cx:948
# cy:370
# Contournr:1cx:986
# cy:646
# Contournr:2cx:656
# cy:634
# Contournr:3cx:996
# cy:577
# Contournr:4cx:922
# cy:632
# Contournr:6cx:983
# cy:508
# Contournr:7cx:914
# cy:441
# Contournr:1cx:984
# cy:646
# Contournr:2cx:652
# cy:634
# Contournr:3cx:992
# cy:579
# Contournr:4cx:917
# cy:632
# Contournr:5cx:994
# cy:511
# Contournr:6cx:979
# cy:513
# Contournr:7cx:885
# cy:498
# Contournr:8cx:943
# cy:370
# Contournr:1cx:981
# cy:646
# Contournr:2cx:647
# cy:634
# Contournr:3cx:893
# cy:643
# Contournr:4cx:988
# cy:580
# Contournr:5cx:940
# cy:615
# Contournr:6cx:992
# cy:513
# Contournr:7cx:977
# cy:517
# Contournr:8cx:881
# cy:498
# Contournr:9cx:939
# cy:371
# Contournr:1cx:979
# cy:646
# Contournr:2cx:642
# cy:634
# Contournr:3cx:888
# cy:643
# Contournr:4cx:985
# cy:581
# Contournr:5cx:935
# cy:616
# Contournr:6cx:990
# cy:515
# Contournr:7cx:974
# cy:522
# Contournr:8cx:904
# cy:440
# Contournr:1cx:976
# cy:646
# Contournr:2cx:637
# cy:634
# Contournr:3cx:883
# cy:643
# Contournr:4cx:980
# cy:582
# Contournr:5cx:930
# cy:616
# Contournr:7cx:975
# cy:524
# Contournr:8cx:900
# cy:441
# Contournr:1cx:974
# cy:645
# Contournr:2cx:632
# cy:635
# Contournr:3cx:878
# cy:643
# Contournr:4cx:976
# cy:582
# Contournr:5cx:925
# cy:616
# Contournr:7cx:973
# cy:528
# Contournr:8cx:896
# cy:441
# Contournr:1cx:627
# cy:635
# Contournr:2cx:873
# cy:643
# Contournr:3cx:970
# cy:582
# Contournr:4cx:920
# cy:616
# Contournr:5cx:984
# cy:520
# Contournr:6cx:970
# cy:613
# Contournr:7cx:892
# cy:442
# Contournr:1cx:622
# cy:635
# Objekt 1 im Scannbereich erkannt und gezählt!
# Contournr:2cx:868
# cy:643
# Contournr:3cx:966
# cy:582
# Contournr:4cx:915
# cy:616
# Contournr:5cx:981
# cy:522
# Contournr:6cx:968
# cy:614
# Contournr:7cx:888
# cy:442
# Contournr:1cx:617
# cy:635
# Contournr:2cx:862
# cy:643
# Contournr:3cx:961
# cy:582
# Contournr:4cx:910
# cy:616
# Contournr:5cx:966
# cy:606
# Contournr:6cx:884
# cy:443
# Contournr:1cx:612
# cy:635
# Contournr:2cx:857
# cy:643
# Contournr:3cx:905
# cy:616
# Contournr:4cx:977
# cy:526
# Contournr:5cx:961
# cy:615
# Contournr:6cx:881
# cy:443
# Contournr:1cx:607
# cy:635
# Contournr:2cx:852
# cy:644
# Contournr:3cx:951
# cy:582
# Contournr:4cx:900
# cy:616
# Contournr:5cx:975
# cy:528
# Contournr:6cx:957
# cy:617
# Contournr:7cx:851
# cy:499
# Contournr:8cx:907
# cy:379
# Contournr:1cx:602
# cy:635
# Contournr:2cx:847
# cy:644
# Contournr:3cx:946
# cy:582
# Contournr:4cx:895
# cy:616
# Contournr:5cx:972
# cy:530
# Contournr:6cx:953
# cy:617
# Contournr:7cx:997
# cy:440
# Contournr:8cx:872
# cy:444
# Contournr:1cx:598
# cy:635
# Contournr:2cx:842
# cy:644
# Contournr:3cx:890
# cy:616
# Contournr:4cx:970
# cy:532
# Contournr:5cx:949
# cy:617
# Contournr:6cx:995
# cy:442
# Contournr:7cx:868
# cy:445
# Contournr:1cx:593
# cy:635
# Contournr:2cx:837
# cy:644
# Contournr:3cx:885
# cy:616
# Contournr:4cx:949
# cy:606
# Contournr:5cx:994
# cy:443
# Contournr:6cx:864
# cy:445
# Contournr:1cx:588
# cy:635
# Contournr:2cx:832
# cy:644
# Contournr:3cx:880
# cy:616
# Contournr:4cx:965
# cy:536
# Contournr:5cx:942
# cy:619
# Contournr:6cx:992
# cy:445
# Contournr:7cx:860
# cy:446
# Contournr:1cx:583
# cy:635
# Contournr:2cx:827
# cy:644
# Contournr:3cx:875
# cy:616
# Contournr:4cx:963
# cy:537
# Contournr:5cx:938
# cy:620
# Contournr:6cx:990
# cy:446
# Contournr:7cx:832
# cy:500
# Contournr:8cx:925
# cy:437
# Contournr:9cx:868
# cy:360
# Contournr:1cx:578
# cy:635
# Contournr:2cx:822
# cy:644
# Contournr:3cx:922
# cy:583
# Contournr:4cx:870
# cy:616
# Contournr:5cx:960
# cy:539
# Contournr:6cx:934
# cy:622
# Contournr:7cx:988
# cy:447
# Contournr:8cx:828
# cy:500
# Contournr:9cx:881
# cy:384
# Contournr:1cx:573
# cy:636
# Contournr:2cx:816
# cy:645
# Contournr:3cx:865
# cy:616
# Contournr:4cx:958
# cy:542
# Contournr:6cx:929
# cy:621
# Contournr:7cx:986
# cy:448
# Contournr:8cx:824
# cy:501
# Contournr:9cx:877
# cy:385
# Contournr:1cx:569
# cy:636
# Contournr:2cx:811
# cy:645
# Contournr:3cx:860
# cy:617
# Contournr:4cx:955
# cy:543
# Contournr:5cx:924
# cy:621
# Contournr:6cx:984
# cy:449
# Contournr:7cx:820
# cy:501
# Contournr:8cx:873
# cy:386
# Contournr:1cx:565
# cy:636
# Contournr:2cx:806
# cy:645
# Contournr:3cx:855
# cy:617
# Contournr:4cx:953
# cy:545
# Contournr:5cx:919
# cy:622
# Contournr:6cx:981
# cy:450
# Contournr:7cx:816
# cy:501
# Contournr:8cx:913
# cy:443
# Contournr:9cx:848
# cy:360
# Contournr:1cx:562
# cy:636
# Contournr:2cx:801
# cy:645
# Contournr:3cx:997
# cy:552
# Contournr:4cx:850
# cy:616
# Contournr:5cx:950
# cy:547
# Contournr:6cx:914
# cy:622
# Contournr:7cx:979
# cy:451
# Contournr:8cx:813
# cy:502
# Contournr:9cx:865
# cy:388
# Contournr:1cx:559
# cy:636
# Contournr:2cx:796
# cy:645
# Contournr:3cx:995
# cy:555
# Contournr:4cx:845
# cy:617
# Contournr:5cx:917
# cy:607
# Contournr:6cx:977
# cy:452
# Contournr:7cx:833
# cy:450
# Contournr:1cx:557
# cy:637
# Contournr:2cx:791
# cy:645
# Contournr:3cx:993
# cy:558
# Contournr:4cx:840
# cy:617
# Contournr:5cx:945
# cy:550
# Contournr:6cx:904
# cy:622
# Contournr:7cx:975
# cy:453
# Contournr:8cx:806
# cy:502
# Contournr:9cx:857
# cy:390
# Contournr:1cx:555
# cy:637
# Contournr:2cx:785
# cy:645
# Contournr:3cx:990
# cy:560
# Contournr:4cx:835
# cy:617
# Contournr:5cx:942
# cy:552
# Contournr:6cx:899
# cy:622
# Contournr:7cx:972
# cy:454
# Contournr:8cx:802
# cy:503
# Contournr:9cx:901
# cy:448
# Contournr:10cx:828
# cy:361
# Contournr:2cx:552
# cy:638
# Contournr:3cx:780
# cy:645
# Contournr:4cx:987
# cy:561
# Contournr:5cx:830
# cy:617
# Contournr:6cx:940
# cy:554
# Contournr:7cx:894
# cy:623
# Contournr:8cx:970
# cy:455
# Contournr:9cx:799
# cy:503
# Contournr:10cx:898
# cy:450
# Contournr:11cx:823
# cy:361
# Contournr:1cx:550
# cy:638
# Contournr:2cx:775
# cy:645
# Contournr:3cx:825
# cy:617
# Contournr:4cx:937
# cy:556
# Contournr:5cx:889
# cy:623
# Contournr:6cx:967
# cy:456
# Contournr:7cx:820
# cy:454
# Contournr:1cx:547
# cy:638
# Contournr:2cx:770
# cy:646
# Contournr:3cx:820
# cy:617
# Contournr:4cx:897
# cy:607
# Contournr:5cx:965
# cy:457
# Contournr:7cx:816
# cy:455
# Contournr:1cx:545
# cy:639
# Contournr:2cx:765
# cy:646
# Contournr:3cx:815
# cy:617
# Contournr:4cx:932
# cy:559
# Contournr:5cx:879
# cy:623
# Contournr:6cx:962
# cy:458
# Contournr:7cx:793
# cy:506
# Contournr:8cx:837
# cy:395
# Contournr:1cx:543
# cy:639
# Contournr:3cx:760
# cy:646
# Contournr:4cx:968
# cy:562
# Contournr:5cx:810
# cy:618
# Contournr:6cx:929
# cy:561
# Contournr:7cx:874
# cy:623
# Contournr:8cx:960
# cy:459
# Contournr:9cx:808
# cy:456
# Contournr:1cx:540
# cy:640
# Contournr:3cx:755
# cy:646
# Contournr:4cx:805
# cy:618
# Contournr:5cx:927
# cy:563
# Contournr:6cx:869
# cy:623
# Contournr:7cx:957
# cy:460
# Contournr:8cx:805
# cy:457
# Contournr:1cx:538
# cy:640
# Contournr:3cx:750
# cy:646
# Contournr:4cx:800
# cy:618
# Contournr:5cx:880
# cy:608
# Contournr:6cx:955
# cy:461
# Contournr:7cx:801
# cy:458
# Contournr:1cx:535
# cy:640
# Contournr:2cx:745
# cy:646
# Contournr:3cx:795
# cy:618
# Contournr:4cx:922
# cy:567
# Contournr:5cx:859
# cy:623
# Contournr:6cx:952
# cy:462
# Contournr:7cx:797
# cy:458
# Contournr:1cx:533
# cy:641
# Contournr:2cx:739
# cy:646
# Contournr:3cx:790
# cy:618
# Contournr:4cx:920
# cy:569
# Contournr:5cx:853
# cy:624
# Contournr:6cx:949
# cy:463
# Contournr:7cx:777
# cy:509
# Contournr:8cx:816
# cy:399
# Contournr:1cx:531
# cy:641
# Contournr:3cx:734
# cy:646
# Contournr:4cx:836
# cy:584
# Contournr:5cx:785
# cy:618
# Contournr:6cx:918
# cy:571
# Contournr:7cx:848
# cy:624
# Contournr:8cx:947
# cy:464
# Contournr:9cx:789
# cy:460
# Contournr:1cx:528
# cy:642
# Contournr:3cx:729
# cy:646
# Contournr:4cx:832
# cy:585
# Contournr:5cx:780
# cy:618
# Contournr:6cx:915
# cy:573
# Contournr:7cx:843
# cy:625
# Contournr:8cx:944
# cy:466
# Contournr:9cx:786
# cy:460
# Contournr:1cx:526
# cy:642
# Contournr:2cx:724
# cy:646
# Contournr:3cx:826
# cy:584
# Contournr:4cx:775
# cy:618
# Contournr:5cx:913
# cy:575
# Contournr:6cx:838
# cy:625
# Contournr:7cx:942
# cy:467
# Contournr:8cx:783
# cy:462
# Contournr:1cx:523
# cy:642
# Contournr:2cx:719
# cy:646
# Contournr:3cx:770
# cy:619
# Contournr:4cx:911
# cy:577
# Contournr:5cx:833
# cy:624
# Contournr:6cx:939
# cy:468
# Contournr:7cx:779
# cy:463
# Contournr:1cx:521
# cy:643
# Contournr:2cx:714
# cy:646
# Contournr:3cx:765
# cy:618
# Contournr:4cx:910
# cy:580
# Contournr:5cx:828
# cy:624
# Contournr:6cx:937
# cy:469
# Contournr:7cx:774
# cy:463
# Contournr:1cx:519
# cy:643
# Contournr:2cx:709
# cy:647
# Contournr:3cx:760
# cy:619
# Contournr:4cx:997
# cy:520
# Contournr:5cx:851
# cy:611
# Contournr:6cx:935
# cy:470
# Contournr:7cx:771
# cy:464
# Contournr:1cx:516
# cy:643
# Contournr:2cx:704
# cy:647
# Contournr:3cx:755
# cy:619
# Contournr:4cx:995
# cy:520
# Contournr:5cx:907
# cy:586
# Contournr:6cx:933
# cy:471
# Contournr:7cx:778
# cy:501
# Contournr:1cx:514
# cy:643
# Contournr:2cx:699
# cy:647
# Contournr:3cx:998
# cy:548
# Contournr:4cx:750
# cy:619
# Contournr:5cx:992
# cy:521
# Contournr:6cx:931
# cy:473
# Contournr:7cx:788
# cy:510
# Contournr:1cx:512
# cy:643
# Contournr:2cx:694
# cy:647
# Contournr:3cx:996
# cy:547
# Contournr:4cx:745
# cy:619
# Contournr:5cx:988
# cy:521
# Contournr:6cx:901
# cy:588
# Contournr:7cx:807
# cy:624
# Contournr:8cx:930
# cy:474
# Contournr:9cx:759
# cy:465
# Contournr:1cx:509
# cy:643
# Contournr:2cx:994
# cy:546
# Contournr:3cx:739
# cy:619
# Contournr:4cx:896
# cy:589
# Contournr:5cx:802
# cy:624
# Contournr:6cx:932
# cy:478
# Contournr:7cx:739
# cy:511
# Contournr:1cx:507
# cy:641
# Contournr:2cx:684
# cy:647
# Contournr:3cx:993
# cy:544
# Contournr:4cx:734
# cy:619
# Contournr:5cx:891
# cy:589
# Contournr:6cx:929
# cy:479
# Contournr:7cx:998
# cy:425
# Contournr:8cx:761
# cy:503
# Contournr:2cx:505
# cy:640
# Contournr:3cx:679
# cy:647
# Contournr:4cx:888
# cy:563
# Contournr:5cx:991
# cy:543
# Contournr:6cx:926
# cy:479
# Contournr:7cx:996
# cy:430
# Contournr:8cx:766
# cy:526
# Contournr:1cx:503
# cy:636
# Contournr:2cx:673
# cy:647
# Contournr:3cx:989
# cy:543
# Contournr:4cx:881
# cy:589
# Contournr:5cx:761
# cy:622
# Contournr:6cx:920
# cy:479
# Contournr:7cx:994
# cy:432
# Contournr:8cx:744
# cy:469
# Contournr:1cx:501
# cy:625
# Contournr:2cx:668
# cy:647
# Contournr:3cx:719
# cy:619
# Contournr:4cx:987
# cy:543
# Contournr:5cx:876
# cy:590
# Contournr:6cx:781
# cy:623
# Contournr:7cx:915
# cy:479
# Contournr:8cx:992
# cy:435
# Contournr:9cx:740
# cy:470
# Contournr:2cx:985
# cy:544
# Contournr:4cx:910
# cy:479
# Contournr:5cx:990
# cy:438
# Contournr:6cx:739
# cy:546
# Contournr:1cx:658
# cy:647
# Contournr:2cx:982
# cy:545
# Contournr:3cx:866
# cy:590
# Contournr:5cx:905
# cy:479
# Contournr:6cx:988
# cy:441
# Contournr:7cx:736
# cy:520
# Contournr:1cx:880
# cy:569
# Contournr:2cx:980
# cy:547
# Contournr:3cx:900
# cy:480
# Contournr:4cx:985
# cy:444
# Contournr:5cx:729
# cy:547
# Contournr:2cx:857
# cy:564
# Contournr:3cx:977
# cy:549
# Contournr:4cx:856
# cy:591
# Contournr:5cx:895
# cy:480
# Contournr:6cx:983
# cy:447
# Contournr:7cx:713
# cy:543
# Contournr:1cx:869
# cy:569
# Contournr:2cx:854
# cy:566
# Contournr:3cx:842
# cy:555
# Contournr:4cx:975
# cy:550
# Contournr:5cx:890
# cy:480
# Contournr:6cx:981
# cy:450
# Contournr:7cx:720
# cy:547
# Contournr:2cx:849
# cy:566
# Contournr:3cx:972
# cy:552
# Contournr:4cx:846
# cy:591
# Contournr:5cx:885
# cy:480
# Contournr:6cx:978
# cy:453
# Contournr:7cx:704
# cy:544
# Contournr:1cx:970
# cy:554
# Contournr:3cx:880
# cy:480
# Contournr:4cx:976
# cy:457
# Contournr:5cx:711
# cy:548
# Contournr:2cx:967
# cy:555
# Contournr:3cx:835
# cy:591
# Contournr:4cx:874
# cy:480
# Contournr:5cx:974
# cy:460
# Contournr:6cx:695
# cy:545
# Contournr:1cx:965
# cy:557
# Contournr:2cx:830
# cy:592
# Contournr:3cx:869
# cy:480
# Contournr:4cx:971
# cy:464
# Contournr:5cx:691
# cy:545
# Contournr:1cx:962
# cy:559
# Contournr:2cx:825
# cy:592
# Contournr:3cx:712
# cy:511
# Contournr:4cx:864
# cy:480
# Contournr:5cx:969
# cy:467
# Contournr:6cx:686
# cy:545
# Contournr:1cx:960
# cy:561
# Contournr:3cx:859
# cy:480
# Contournr:4cx:967
# cy:470
# Contournr:5cx:692
# cy:549
# Contournr:1cx:816
# cy:565
# Contournr:2cx:958
# cy:562
# Contournr:3cx:814
# cy:591
# Contournr:4cx:854
# cy:480
# Contournr:5cx:964
# cy:473
# Contournr:6cx:675
# cy:545
# Contournr:2cx:955
# cy:564
# Contournr:3cx:809
# cy:591
# Contournr:5cx:849
# cy:480
# Contournr:6cx:962
# cy:476
# Contournr:7cx:670
# cy:545
# Contournr:3cx:804
# cy:591
# Contournr:6cx:843
# cy:480
# Contournr:7cx:956
# cy:537
# Contournr:8cx:665
# cy:545
# Contournr:1cx:799
# cy:591
# Contournr:2cx:997
# cy:476
# Contournr:3cx:838
# cy:480
# Contournr:4cx:954
# cy:540
# Contournr:5cx:659
# cy:545
# Contournr:1cx:793
# cy:591
# Contournr:2cx:996
# cy:481
# Contournr:3cx:833
# cy:480
# Contournr:4cx:951
# cy:542
# Contournr:5cx:654
# cy:545
# Contournr:1cx:788
# cy:591
# Contournr:4cx:994
# cy:483
# Contournr:5cx:828
# cy:480
# Contournr:6cx:949
# cy:544
# Contournr:7cx:649
# cy:545
# Contournr:2cx:783
# cy:592
# Contournr:3cx:672
# cy:511
# Contournr:4cx:992
# cy:487
# Contournr:5cx:823
# cy:480
# Contournr:6cx:946
# cy:546
# Contournr:7cx:644
# cy:545
# Contournr:1cx:778
# cy:592
# Contournr:4cx:990
# cy:489
# Contournr:5cx:818
# cy:480
# Contournr:6cx:943
# cy:548
# Contournr:7cx:640
# cy:545
# Contournr:1cx:773
# cy:592
# Contournr:3cx:988
# cy:492
# Contournr:4cx:813
# cy:481
# Contournr:5cx:940
# cy:549
# Contournr:6cx:635
# cy:546
# Contournr:2cx:767
# cy:592
# Contournr:3cx:985
# cy:494
# Contournr:4cx:808
# cy:481
# Contournr:5cx:938
# cy:551
# Contournr:6cx:631
# cy:546
# Contournr:1cx:996
# cy:546
# Contournr:2cx:762
# cy:592
# Contournr:3cx:983
# cy:497
# Contournr:4cx:802
# cy:481
# Contournr:5cx:934
# cy:553
# Contournr:6cx:626
# cy:546
# Contournr:1cx:992
# cy:546
# Contournr:2cx:757
# cy:592
# Contournr:3cx:980
# cy:499
# Contournr:4cx:797
# cy:481
# Contournr:5cx:931
# cy:555
# Contournr:6cx:622
# cy:546
# Objekt 2 im Scannbereich erkannt und gezählt!
# Contournr:1cx:997
# cy:697
# Contournr:3cx:987
# cy:547
# Contournr:4cx:752
# cy:592
# Contournr:5cx:978
# cy:502
# Contournr:6cx:793
# cy:481
# Contournr:7cx:927
# cy:556
# Contournr:8cx:619
# cy:546
# Contournr:1cx:995
# cy:698
# Contournr:3cx:982
# cy:547
# Contournr:4cx:747
# cy:592
# Contournr:5cx:976
# cy:505
# Contournr:6cx:788
# cy:482
# Contournr:7cx:924
# cy:558
# Contournr:8cx:615
# cy:547
# Contournr:1cx:992
# cy:698
# Contournr:3cx:977
# cy:547
# Contournr:4cx:742
# cy:593
# Contournr:5cx:973
# cy:508
# Contournr:6cx:783
# cy:482
# Contournr:7cx:920
# cy:560
# Contournr:8cx:611
# cy:547
# Contournr:1cx:989
# cy:698
# Contournr:2cx:653
# cy:565
# Contournr:3cx:972
# cy:547
# Contournr:4cx:737
# cy:593
# Contournr:5cx:971
# cy:510
# Contournr:6cx:778
# cy:482
# Contournr:7cx:916
# cy:561
# Contournr:8cx:605
# cy:549
# Contournr:1cx:987
# cy:699
# Contournr:2cx:648
# cy:565
# Contournr:3cx:998
# cy:560
# Contournr:4cx:967
# cy:547
# Contournr:5cx:732
# cy:593
# Contournr:7cx:968
# cy:513
# Contournr:9cx:773
# cy:482
# Contournr:10cx:911
# cy:561
# Contournr:11cx:603
# cy:549
# Contournr:1cx:986
# cy:698
# Contournr:3cx:643
# cy:565
# Contournr:4cx:962
# cy:547
# Contournr:5cx:727
# cy:593
# Contournr:6cx:966
# cy:517
# Contournr:7cx:768
# cy:482
# Contournr:8cx:906
# cy:561
# Contournr:9cx:605
# cy:547
# Contournr:1cx:982
# cy:699
# Contournr:2cx:638
# cy:565
# Contournr:3cx:957
# cy:547
# Contournr:4cx:722
# cy:593
# Contournr:5cx:964
# cy:520
# Contournr:6cx:763
# cy:482
# Contournr:7cx:901
# cy:561
# Contournr:8cx:603
# cy:547
# Contournr:1cx:977
# cy:699
# Contournr:2cx:633
# cy:565
# Contournr:3cx:953
# cy:548
# Contournr:4cx:717
# cy:594
# Contournr:5cx:962
# cy:523
# Contournr:6cx:758
# cy:483
# Contournr:7cx:897
# cy:561
# Contournr:8cx:602
# cy:547
# Contournr:1cx:972
# cy:699
# Contournr:2cx:997
# cy:605
# Contournr:3cx:629
# cy:565
# Contournr:4cx:947
# cy:547
# Contournr:5cx:712
# cy:594
# Contournr:6cx:570
# cy:633
# Contournr:7cx:960
# cy:526
# Contournr:8cx:753
# cy:483
# Contournr:9cx:891
# cy:562
# Contournr:10cx:629
# cy:468
# Contournr:1cx:967
# cy:699
# Contournr:2cx:995
# cy:603
# Contournr:3cx:623
# cy:565
# Contournr:4cx:942
# cy:548
# Contournr:5cx:707
# cy:594
# Contournr:6cx:567
# cy:633
# Contournr:7cx:958
# cy:530
# Contournr:8cx:748
# cy:483
# Contournr:9cx:886
# cy:562
# Contournr:10cx:629
# cy:468
# Contournr:1cx:961
# cy:699
# Contournr:2cx:618
# cy:566
# Contournr:3cx:938
# cy:548
# Contournr:4cx:702
# cy:594
# Contournr:5cx:957
# cy:536
# Contournr:6cx:742
# cy:483
# Contournr:7cx:881
# cy:561
# Contournr:8cx:598
# cy:547
# Contournr:1cx:957
# cy:699
# Contournr:2cx:614
# cy:566
# Contournr:3cx:932
# cy:548
# Contournr:4cx:697
# cy:595
# Contournr:5cx:955
# cy:539
# Contournr:6cx:737
# cy:483
# Contournr:7cx:876
# cy:562
# Contournr:8cx:596
# cy:547
# Contournr:1cx:952
# cy:699
# Contournr:2cx:609
# cy:566
# Contournr:3cx:928
# cy:548
# Contournr:4cx:692
# cy:595
# Contournr:6cx:558
# cy:631
# Contournr:7cx:953
# cy:542
# Contournr:8cx:732
# cy:483
# Contournr:9cx:871
# cy:562
# Contournr:10cx:627
# cy:471
# Contournr:1cx:947
# cy:699
# Contournr:2cx:604
# cy:566
# Contournr:3cx:923
# cy:548
# Contournr:4cx:687
# cy:595
# Contournr:5cx:556
# cy:631
# Contournr:6cx:950
# cy:545
# Contournr:7cx:727
# cy:483
# Contournr:8cx:866
# cy:562
# Contournr:9cx:626
# cy:473
# Contournr:1cx:942
# cy:699
# Contournr:2cx:599
# cy:566
# Contournr:3cx:918
# cy:548
# Contournr:4cx:682
# cy:595
# Contournr:5cx:553
# cy:632
# Contournr:6cx:947
# cy:547
# Contournr:7cx:722
# cy:483
# Contournr:8cx:861
# cy:562
# Contournr:9cx:624
# cy:475
# Contournr:1cx:936
# cy:700
# Contournr:2cx:594
# cy:566
# Contournr:3cx:913
# cy:548
# Contournr:4cx:677
# cy:595
# Contournr:5cx:551
# cy:632
# Contournr:6cx:944
# cy:548
# Contournr:7cx:717
# cy:483
# Contournr:8cx:855
# cy:562
# Contournr:9cx:623
# cy:477
# Contournr:1cx:931
# cy:700
# Contournr:3cx:589
# cy:566
# Contournr:4cx:908
# cy:548
# Contournr:5cx:672
# cy:595
# Contournr:6cx:550
# cy:634
# Contournr:7cx:940
# cy:549
# Contournr:8cx:712
# cy:483
# Contournr:9cx:850
# cy:562
# Contournr:10cx:621
# cy:479
# Objekt 3 im Scannbereich erkannt und gezählt!
# Contournr:1cx:926
# cy:700
# Contournr:2cx:584
# cy:566
# Contournr:3cx:903
# cy:548
# Contournr:4cx:667
# cy:595
# Contournr:5cx:548
# cy:635
# Contournr:6cx:935
# cy:549
# Contournr:7cx:707
# cy:483
# Contournr:8cx:845
# cy:562
# Contournr:9cx:619
# cy:482
# Contournr:1cx:921
# cy:700
# Contournr:3cx:579
# cy:566
# Contournr:4cx:898
# cy:548
# Contournr:5cx:662
# cy:596
# Contournr:6cx:547
# cy:637
# Contournr:7cx:929
# cy:549
# Contournr:8cx:655
# cy:547
# Contournr:9cx:701
# cy:483
# Contournr:10cx:840
# cy:562
# Contournr:11cx:593
# cy:440
# Contournr:1cx:916
# cy:700
# Contournr:3cx:574
# cy:566
# Contournr:4cx:893
# cy:549
# Contournr:5cx:657
# cy:596
# Contournr:6cx:545
# cy:639
# Contournr:7cx:925
# cy:550
# Contournr:8cx:652
# cy:549
# Contournr:9cx:697
# cy:484
# Contournr:10cx:500
# cy:440
# Contournr:11cx:835
# cy:562
# Contournr:12cx:593
# cy:443
# Contournr:1cx:911
# cy:700
# Contournr:3cx:570
# cy:566
# Contournr:4cx:888
# cy:549
# Contournr:5cx:504
# cy:531
# Contournr:6cx:652
# cy:596
# Contournr:7cx:546
# cy:642
# Contournr:8cx:920
# cy:550
# Contournr:10cx:650
# cy:551
# Contournr:11cx:692
# cy:484
# Contournr:12cx:830
# cy:562
# Contournr:13cx:594
# cy:447
# Contournr:1cx:906
# cy:700
# Contournr:2cx:505
# cy:729
# Contournr:3cx:500
# cy:671
# Contournr:4cx:565
# cy:567
# Contournr:5cx:883
# cy:549
# Contournr:6cx:501
# cy:532
# Contournr:7cx:647
# cy:596
# Contournr:8cx:548
# cy:633
# Contournr:9cx:914
# cy:550
# Contournr:10cx:648
# cy:552
# Contournr:11cx:686
# cy:484
# Contournr:12cx:824
# cy:562
# Contournr:14cx:595
# cy:452
# Contournr:1cx:503
# cy:736
# Contournr:2cx:901
# cy:700
# Contournr:3cx:972
# cy:579
# Contournr:4cx:560
# cy:567
# Contournr:5cx:878
# cy:549
# Contournr:7cx:641
# cy:596
# Contournr:9cx:545
# cy:635
# Contournr:10cx:909
# cy:550
# Contournr:11cx:645
# cy:554
# Contournr:12cx:681
# cy:484
# Contournr:13cx:766
# cy:546
# Contournr:14cx:501
# cy:400
# Contournr:16cx:520
# cy:357
# Contournr:1cx:501
# cy:742
# Contournr:2cx:896
# cy:700
# Contournr:3cx:964
# cy:583
# Contournr:4cx:967
# cy:580
# Contournr:6cx:555
# cy:567
# Contournr:7cx:873
# cy:549
# Contournr:8cx:637
# cy:596
# Contournr:9cx:742
# cy:508
# Contournr:10cx:542
# cy:636
# Contournr:11cx:904
# cy:551
# Contournr:12cx:643
# cy:556
# Contournr:13cx:676
# cy:484
# Contournr:14cx:763
# cy:547
# Contournr:15cx:568
# cy:385
# Contournr:16cx:517
# cy:357
# Contournr:2cx:891
# cy:700
# Contournr:3cx:958
# cy:582
# Contournr:4cx:962
# cy:579
# Contournr:5cx:550
# cy:567
# Contournr:6cx:868
# cy:549
# Contournr:7cx:997
# cy:523
# Contournr:8cx:539
# cy:636
# Contournr:9cx:632
# cy:596
# Contournr:10cx:899
# cy:551
# Contournr:11cx:641
# cy:558
# Contournr:12cx:671
# cy:484
# Contournr:13cx:760
# cy:549
# Contournr:14cx:564
# cy:385
# Contournr:15cx:515
# cy:357
# Contournr:1cx:886
# cy:700
# Contournr:2cx:957
# cy:580
# Contournr:3cx:545
# cy:567
# Contournr:4cx:863
# cy:549
# Contournr:5cx:537
# cy:637
# Contournr:6cx:627
# cy:597
# Contournr:7cx:995
# cy:521
# Contournr:8cx:895
# cy:551
# Contournr:9cx:638
# cy:559
# Contournr:10cx:666
# cy:484
# Contournr:11cx:756
# cy:549
# Contournr:12cx:559
# cy:386
# Contournr:13cx:513
# cy:357
# Contournr:1cx:881
# cy:701
# Contournr:2cx:949
# cy:582
# Contournr:3cx:952
# cy:580
# Contournr:4cx:858
# cy:549
# Contournr:5cx:534
# cy:638
# Contournr:6cx:622
# cy:597
# Objekt 4 im Scannbereich erkannt und gezählt!
# Contournr:7cx:993
# cy:520
# Contournr:8cx:889
# cy:551
# Contournr:9cx:635
# cy:561
# Contournr:10cx:661
# cy:485
# Contournr:11cx:753
# cy:550
# Contournr:12cx:554
# cy:386
# Contournr:13cx:511
# cy:358
# Contournr:1cx:876
# cy:701
# Contournr:2cx:944
# cy:583
# Contournr:3cx:947
# cy:579
# Contournr:4cx:535
# cy:567
# Contournr:5cx:853
# cy:549
# Contournr:6cx:532
# cy:638
# Contournr:7cx:617
# cy:597
# Contournr:8cx:722
# cy:508
# Contournr:9cx:990
# cy:520
# Contournr:10cx:884
# cy:551
# Contournr:11cx:633
# cy:563
# Contournr:12cx:656
# cy:485
# Contournr:13cx:749
# cy:551
# Contournr:14cx:549
# cy:387
# Contournr:15cx:509
# cy:359
# Contournr:1cx:871
# cy:701
# Contournr:2cx:942
# cy:580
# Contournr:3cx:531
# cy:567
# Contournr:4cx:848
# cy:549
# Contournr:5cx:529
# cy:639
# Contournr:6cx:612
# cy:597
# Contournr:7cx:988
# cy:520
# Contournr:8cx:630
# cy:564
# Contournr:9cx:879
# cy:552
# Contournr:10cx:651
# cy:485
# Contournr:11cx:745
# cy:552
# Contournr:12cx:545
# cy:387
# Contournr:13cx:507
# cy:360
# Contournr:1cx:866
# cy:701
# Contournr:2cx:936
# cy:580
# Contournr:3cx:526
# cy:567
# Contournr:4cx:527
# cy:639
# Contournr:5cx:843
# cy:549
# Contournr:6cx:607
# cy:597
# Contournr:7cx:985
# cy:520
# Contournr:8cx:628
# cy:566
# Contournr:9cx:874
# cy:551
# Contournr:10cx:646
# cy:485
# Contournr:11cx:742
# cy:553
# Contournr:12cx:540
# cy:387
# Contournr:13cx:505
# cy:361
# Contournr:1cx:861
# cy:701
# Contournr:2cx:928
# cy:583
# Contournr:3cx:932
# cy:580
# Contournr:4cx:521
# cy:568
# Contournr:5cx:525
# cy:641
# Contournr:6cx:839
# cy:550
# Contournr:7cx:604
# cy:599
# Contournr:8cx:981
# cy:521
# Contournr:9cx:625
# cy:568
# Contournr:10cx:869
# cy:552
# Contournr:11cx:641
# cy:485
# Contournr:12cx:739
# cy:553
# Contournr:13cx:535
# cy:387
# Contournr:14cx:503
# cy:364
# Contournr:1cx:856
# cy:701
# Contournr:3cx:923
# cy:583
# Contournr:4cx:927
# cy:580
# Contournr:5cx:523
# cy:642
# Contournr:6cx:516
# cy:568
# Contournr:7cx:834
# cy:550
# Contournr:8cx:601
# cy:600
# Contournr:9cx:978
# cy:521
# Contournr:10cx:622
# cy:569
# Objekt 5 im Scannbereich erkannt und gezählt!
# Contournr:11cx:864
# cy:552
# Contournr:12cx:636
# cy:485
# Contournr:13cx:735
# cy:554
# Contournr:14cx:530
# cy:387
# Contournr:15cx:502
# cy:367
# Contournr:1cx:851
# cy:701
# Contournr:2cx:997
# cy:680
# Contournr:3cx:922
# cy:580
# Contournr:4cx:521
# cy:643
# Contournr:5cx:512
# cy:568
# Contournr:6cx:829
# cy:550
# Contournr:7cx:598
# cy:602
# Contournr:8cx:975
# cy:522
# Contournr:9cx:620
# cy:571
# Objekt 6 im Scannbereich erkannt und gezählt!
# Contournr:10cx:859
# cy:552
# Contournr:11cx:631
# cy:485
# Contournr:12cx:732
# cy:555
# Contournr:13cx:525
# cy:387
# Contournr:14cx:500
# cy:371
# Contournr:1cx:846
# cy:701
# Contournr:2cx:995
# cy:679
# Contournr:3cx:916
# cy:581
# Contournr:4cx:519
# cy:645
# Contournr:5cx:506
# cy:567
# Contournr:6cx:824
# cy:550
# Contournr:7cx:595
# cy:603
# Contournr:8cx:973
# cy:523
# Contournr:9cx:617
# cy:572
# Contournr:10cx:854
# cy:552
# Contournr:11cx:626
# cy:485
# Contournr:12cx:728
# cy:556
# Contournr:13cx:521
# cy:387
# Contournr:1cx:841
# cy:701
# Contournr:2cx:992
# cy:677
# Contournr:3cx:911
# cy:580
# Contournr:4cx:517
# cy:647
# Contournr:5cx:502
# cy:568
# Contournr:6cx:819
# cy:550
# Contournr:7cx:592
# cy:605
# Contournr:8cx:969
# cy:523
# Contournr:9cx:614
# cy:574
# Contournr:10cx:848
# cy:552
# Contournr:11cx:621
# cy:485
# Objekt 7 im Scannbereich erkannt und gezählt!
# Contournr:12cx:724
# cy:557
# Contournr:13cx:516
# cy:387
# Contournr:1cx:836
# cy:701
# Contournr:2cx:991
# cy:675
# Contournr:3cx:518
# cy:654
# Contournr:4cx:903
# cy:584
# Contournr:5cx:501
# cy:587
# Contournr:6cx:906
# cy:581
# Contournr:7cx:814
# cy:550
# Contournr:8cx:589
# cy:607
# Contournr:9cx:682
# cy:510
# Contournr:10cx:966
# cy:524
# Contournr:11cx:611
# cy:575
# Contournr:12cx:843
# cy:552
# Contournr:13cx:616
# cy:485
# Contournr:14cx:720
# cy:557
# Contournr:15cx:511
# cy:387
# Contournr:1cx:831
# cy:702
# Contournr:2cx:988
# cy:674
# Contournr:3cx:502
# cy:676
# Contournr:4cx:518
# cy:653
# Contournr:5cx:897
# cy:583
# Contournr:6cx:901
# cy:581
# Contournr:7cx:890
# cy:576
# Contournr:8cx:809
# cy:550
# Contournr:9cx:586
# cy:609
# Contournr:10cx:677
# cy:510
# Contournr:11cx:962
# cy:524
# Contournr:12cx:608
# cy:577
# Contournr:13cx:838
# cy:552
# Contournr:14cx:610
# cy:485
# Contournr:15cx:717
# cy:558
# Contournr:16cx:506
# cy:388
# Contournr:1cx:826
# cy:702
# Contournr:2cx:501
# cy:681
# Contournr:3cx:986
# cy:672
# Contournr:4cx:516
# cy:657
# Contournr:5cx:896
# cy:581
# Contournr:6cx:804
# cy:550
# Contournr:7cx:583
# cy:610
# Contournr:8cx:605
# cy:578
# Contournr:9cx:958
# cy:525
# Contournr:10cx:833
# cy:552
# Contournr:11cx:605
# cy:486
# Contournr:12cx:713
# cy:558
# Contournr:13cx:501
# cy:387
# Contournr:1cx:821
# cy:702
# Contournr:2cx:984
# cy:671
# Contournr:3cx:513
# cy:660
# Contournr:4cx:887
# cy:583
# Contournr:5cx:891
# cy:581
# Contournr:6cx:799
# cy:550
# Contournr:7cx:581
# cy:612
# Contournr:8cx:997
# cy:536
# Contournr:9cx:603
# cy:580
# Contournr:10cx:667
# cy:510
# Contournr:11cx:953
# cy:525
# Contournr:12cx:828
# cy:552
# Contournr:13cx:600
# cy:486
# Contournr:15cx:709
# cy:559
# Contournr:16cx:997
# cy:413
# Contournr:1cx:816
# cy:702
# Contournr:2cx:981
# cy:670
# Contournr:3cx:510
# cy:663
# Contournr:4cx:886
# cy:581
# Contournr:5cx:794
# cy:550
# Contournr:6cx:997
# cy:554
# Contournr:7cx:578
# cy:614
# Contournr:9cx:992
# cy:536
# Contournr:10cx:599
# cy:581
# Contournr:11cx:662
# cy:510
# Contournr:12cx:948
# cy:525
# Contournr:14cx:822
# cy:552
# Contournr:15cx:595
# cy:486
# Contournr:16cx:706
# cy:560
# Contournr:17cx:995
# cy:425
# Contournr:1cx:811
# cy:702
# Contournr:2cx:979
# cy:668
# Contournr:3cx:509
# cy:665
# Contournr:4cx:876
# cy:584
# Contournr:5cx:880
# cy:581
# Contournr:6cx:789
# cy:551
# Contournr:7cx:575
# cy:616
# Contournr:8cx:995
# cy:555
# Contournr:10cx:987
# cy:536
# Contournr:13cx:998
# cy:522
# Contournr:14cx:596
# cy:582
# Contournr:15cx:656
# cy:510
# Contournr:16cx:942
# cy:525
# Contournr:17cx:817
# cy:553
# Contournr:18cx:590
# cy:486
# Contournr:19cx:702
# cy:560
# Contournr:20cx:994
# cy:439
# Contournr:1cx:806
# cy:702
# Contournr:2cx:976
# cy:666
# Contournr:3cx:507
# cy:667
# Contournr:4cx:871
# cy:584
# Contournr:5cx:875
# cy:581
# Contournr:7cx:572
# cy:618
# Contournr:8cx:784
# cy:551
# Contournr:10cx:982
# cy:536
# Contournr:11cx:593
# cy:584
# Contournr:13cx:651
# cy:510
# Contournr:14cx:937
# cy:525
# Contournr:15cx:812
# cy:553
# Contournr:16cx:585
# cy:486
# Contournr:17cx:698
# cy:561
# Contournr:18cx:992
# cy:467
# Contournr:1cx:801
# cy:702
# Contournr:2cx:506
# cy:669
# Contournr:3cx:973
# cy:665
# Contournr:4cx:866
# cy:584
# Contournr:5cx:871
# cy:581
# Contournr:6cx:570
# cy:620
# Contournr:7cx:779
# cy:551
# Contournr:8cx:977
# cy:536
# Contournr:9cx:590
# cy:585
# Contournr:11cx:646
# cy:510
# Contournr:12cx:931
# cy:525
# Contournr:13cx:807
# cy:553
# Contournr:14cx:581
# cy:486
# Contournr:15cx:694
# cy:561
# Contournr:16cx:989
# cy:472
# Contournr:1cx:796
# cy:702
# Contournr:2cx:505
# cy:669
# Contournr:3cx:971
# cy:663
# Contournr:4cx:861
# cy:585
# Contournr:5cx:865
# cy:581
# Contournr:6cx:567
# cy:621
# Contournr:7cx:774
# cy:551
# Contournr:8cx:972
# cy:537
# Contournr:9cx:587
# cy:586
# Contournr:10cx:642
# cy:510
# Contournr:11cx:926
# cy:525
# Contournr:12cx:802
# cy:553
# Contournr:13cx:577
# cy:487
# Contournr:14cx:690
# cy:562
# Contournr:15cx:986
# cy:478
# Contournr:1cx:791
# cy:702
# Contournr:2cx:503
# cy:667
# Contournr:3cx:968
# cy:662
# Contournr:4cx:855
# cy:584
# Contournr:5cx:860
# cy:581
# Contournr:6cx:564
# cy:623
# Contournr:7cx:769
# cy:551
# Contournr:8cx:967
# cy:537
# Contournr:9cx:584
# cy:587
# Contournr:11cx:637
# cy:510
# Contournr:12cx:921
# cy:525
# Contournr:13cx:797
# cy:553
# Contournr:14cx:574
# cy:488
# Contournr:15cx:686
# cy:562
# Contournr:16cx:983
# cy:483
# Contournr:1cx:786
# cy:702
# Contournr:2cx:502
# cy:665
# Contournr:3cx:965
# cy:661
# Contournr:4cx:855
# cy:582
# Contournr:5cx:561
# cy:625
# Contournr:6cx:764
# cy:551
# Contournr:8cx:962
# cy:537
# Contournr:9cx:581
# cy:588
# Contournr:10cx:632
# cy:511
# Contournr:11cx:916
# cy:526
# Contournr:12cx:792
# cy:553
# Contournr:13cx:571
# cy:489
# Contournr:14cx:682
# cy:563
# Contournr:15cx:979
# cy:486
# Contournr:1cx:781
# cy:702
# Contournr:3cx:962
# cy:659
# Contournr:4cx:998
# cy:608
# Contournr:5cx:845
# cy:585
# Contournr:7cx:850
# cy:582
# Contournr:8cx:559
# cy:626
# Contournr:9cx:759
# cy:551
# Contournr:10cx:578
# cy:589
# Contournr:11cx:956
# cy:537
# Contournr:13cx:627
# cy:511
# Contournr:14cx:911
# cy:526
# Contournr:15cx:787
# cy:553
# Contournr:16cx:569
# cy:490
# Contournr:17cx:678
# cy:563
# Contournr:18cx:974
# cy:488
# Contournr:1cx:776
# cy:702
# Contournr:2cx:960
# cy:658
# Contournr:3cx:996
# cy:606
# Contournr:4cx:839
# cy:585
# Contournr:7cx:845
# cy:582
# Contournr:8cx:556
# cy:628
# Contournr:10cx:754
# cy:551
# Contournr:11cx:575
# cy:591
# Contournr:12cx:951
# cy:537
# Contournr:13cx:622
# cy:511
# Objekt 8 im Scannbereich erkannt und gezählt!
# Contournr:14cx:906
# cy:526
# Contournr:15cx:782
# cy:553
# Contournr:16cx:566
# cy:491
# Contournr:17cx:674
# cy:564
# Contournr:18cx:970
# cy:491
# Contournr:1cx:771
# cy:703
# Contournr:2cx:956
# cy:657
# Contournr:3cx:993
# cy:605
# Contournr:4cx:840
# cy:582
# Contournr:5cx:553
# cy:630
# Contournr:6cx:749
# cy:551
# Contournr:7cx:572
# cy:592
# Contournr:8cx:946
# cy:538
# Contournr:9cx:998
# cy:528
# Contournr:11cx:617
# cy:511
# Contournr:12cx:900
# cy:526
# Contournr:13cx:777
# cy:553
# Contournr:14cx:563
# cy:492
# Contournr:15cx:670
# cy:564
# Contournr:16cx:965
# cy:492
# Contournr:1cx:766
# cy:703
# Contournr:2cx:954
# cy:656
# Contournr:3cx:991
# cy:603
# Contournr:4cx:829
# cy:583
# Contournr:5cx:551
# cy:632
# Contournr:6cx:835
# cy:582
# Contournr:8cx:744
# cy:551
# Contournr:9cx:570
# cy:593
# Contournr:10cx:941
# cy:537
# Contournr:11cx:996
# cy:529
# Contournr:12cx:612
# cy:511
# Contournr:13cx:896
# cy:526
# Contournr:14cx:772
# cy:553
# Contournr:15cx:560
# cy:493
# Contournr:16cx:666
# cy:564
# Contournr:17cx:961
# cy:493
# Contournr:1cx:761
# cy:703
# Contournr:2cx:997
# cy:653
# Contournr:3cx:951
# cy:654
# Contournr:4cx:989
# cy:601
# Contournr:5cx:548
# cy:634
# Contournr:6cx:825
# cy:585
# Contournr:7cx:830
# cy:582
# Contournr:8cx:996
# cy:559
# Contournr:9cx:998
# cy:553
# Contournr:10cx:740
# cy:552
# Contournr:11cx:568
# cy:595
# Contournr:12cx:936
# cy:537
# Contournr:13cx:991
# cy:529
# Contournr:15cx:607
# cy:511
# Contournr:16cx:890
# cy:526
# Contournr:17cx:767
# cy:553
# Contournr:18cx:558
# cy:494
# Contournr:19cx:662
# cy:565
# Contournr:20cx:956
# cy:493
# Contournr:1cx:756
# cy:703
# Contournr:2cx:995
# cy:652
# Contournr:4cx:949
# cy:653
# Contournr:5cx:545
# cy:636
# Contournr:6cx:987
# cy:599
# Contournr:10cx:825
# cy:582
# Contournr:12cx:994
# cy:562
# Contournr:13cx:998
# cy:555
# Contournr:14cx:993
# cy:553
# Contournr:15cx:735
# cy:552
# Contournr:16cx:567
# cy:597
# Contournr:17cx:931
# cy:538
# Contournr:18cx:986
# cy:529
# Contournr:19cx:997
# cy:517
# Contournr:20cx:602
# cy:511
# Contournr:21cx:885
# cy:526
# Contournr:22cx:762
# cy:553
# Contournr:23cx:555
# cy:496
# Contournr:24cx:658
# cy:565
# Contournr:25cx:951
# cy:493
# Contournr:1cx:751
# cy:703
# Contournr:2cx:992
# cy:652
# Contournr:4cx:947
# cy:651
# Contournr:5cx:542
# cy:637
# Contournr:6cx:985
# cy:598
# Contournr:7cx:820
# cy:582
# Contournr:8cx:993
# cy:563
# Contournr:9cx:730
# cy:552
# Contournr:10cx:566
# cy:600
# Contournr:11cx:926
# cy:538
# Contournr:12cx:981
# cy:529
# Contournr:14cx:597
# cy:511
# Contournr:15cx:995
# cy:517
# Contournr:16cx:880
# cy:526
# Contournr:17cx:757
# cy:554
# Contournr:18cx:553
# cy:497
# Contournr:19cx:654
# cy:566
# Contournr:20cx:945
# cy:493
# Contournr:1cx:746
# cy:703
# Contournr:2cx:991
# cy:654
# Contournr:3cx:580
# cy:638
# Contournr:4cx:945
# cy:650
# Contournr:5cx:539
# cy:639
# Contournr:6cx:815
# cy:582
# Contournr:7cx:983
# cy:596
# Contournr:8cx:725
# cy:552
# Contournr:9cx:991
# cy:562
# Contournr:10cx:998
# cy:546
# Contournr:11cx:565
# cy:603
# Contournr:12cx:921
# cy:538
# Contournr:13cx:976
# cy:530
# Contournr:14cx:592
# cy:512
# Contournr:15cx:875
# cy:526
# Contournr:16cx:993
# cy:517
# Contournr:17cx:752
# cy:554
# Contournr:18cx:550
# cy:498
# Contournr:19cx:650
# cy:566
# Contournr:20cx:940
# cy:493
# Contournr:2cx:998
# cy:728
# Contournr:3cx:998
# cy:723
# Contournr:4cx:998
# cy:718
# Contournr:5cx:998
# cy:714
# Contournr:6cx:998
# cy:709
# Contournr:7cx:741
# cy:703
# Contournr:8cx:990
# cy:658
# Contournr:9cx:575
# cy:638
# Contournr:10cx:942
# cy:648
# Contournr:11cx:536
# cy:641
# Contournr:13cx:804
# cy:585
# Contournr:14cx:809
# cy:582
# Contournr:15cx:980
# cy:594
# Contournr:16cx:720
# cy:552
# Contournr:17cx:564
# cy:606
# Contournr:18cx:988
# cy:561
# Contournr:19cx:916
# cy:538
# Contournr:20cx:971
# cy:529
# Contournr:21cx:587
# cy:512
# Contournr:22cx:870
# cy:526
# Contournr:23cx:990
# cy:515
# Contournr:24cx:746
# cy:554
# Contournr:25cx:547
# cy:499
# Contournr:26cx:645
# cy:566
# Contournr:27cx:935
# cy:493
# Contournr:1cx:736
# cy:703
# Contournr:2cx:990
# cy:675
# Contournr:3cx:570
# cy:639
# Contournr:4cx:940
# cy:647
# Contournr:5cx:534
# cy:642
# Contournr:7cx:798
# cy:585
# Contournr:8cx:804
# cy:583
# Contournr:9cx:977
# cy:593
# Contournr:11cx:971
# cy:553
# Contournr:12cx:715
# cy:552
# Contournr:13cx:563
# cy:609
# Contournr:14cx:986
# cy:559
# Contournr:15cx:911
# cy:538
# Contournr:16cx:966
# cy:530
# Contournr:17cx:582
# cy:512
# Contournr:18cx:865
# cy:526
# Contournr:19cx:988
# cy:514
# Contournr:20cx:741
# cy:554
# Contournr:21cx:545
# cy:500
# Contournr:22cx:641
# cy:567
# Contournr:23cx:998
# cy:422
# Contournr:24cx:930
# cy:493
# Contournr:1cx:731
# cy:703
# Contournr:2cx:988
# cy:682
# Contournr:3cx:565
# cy:639
# Contournr:4cx:938
# cy:645
# Contournr:5cx:531
# cy:644
# Contournr:6cx:793
# cy:585
# Contournr:7cx:799
# cy:583
# Contournr:9cx:975
# cy:591
# Contournr:10cx:562
# cy:611
# Contournr:11cx:500
# cy:557
# Contournr:12cx:710
# cy:552
# Contournr:13cx:983
# cy:557
# Contournr:14cx:906
# cy:538
# Contournr:15cx:961
# cy:530
# Contournr:17cx:577
# cy:512
# Contournr:18cx:859
# cy:527
# Contournr:19cx:985
# cy:513
# Contournr:20cx:736
# cy:554
# Contournr:21cx:542
# cy:501
# Contournr:22cx:637
# cy:567
# Contournr:23cx:995
# cy:422
# Contournr:24cx:925
# cy:494
# Contournr:1cx:726
# cy:703
# Contournr:2cx:987
# cy:683
# Contournr:4cx:560
# cy:639
# Contournr:5cx:528
# cy:646
# Contournr:6cx:936
# cy:643
# Contournr:7cx:794
# cy:583
# Contournr:9cx:559
# cy:613
# Contournr:10cx:972
# cy:589
# Contournr:11cx:705
# cy:552
# Contournr:12cx:901
# cy:538
# Contournr:13cx:980
# cy:555
# Contournr:14cx:998
# cy:528
# Contournr:15cx:956
# cy:530
# Contournr:16cx:572
# cy:512
# Contournr:17cx:854
# cy:527
# Contournr:18cx:981
# cy:512
# Contournr:19cx:731
# cy:554
# Contournr:20cx:539
# cy:502
# Contournr:21cx:633
# cy:567
# Contournr:22cx:994
# cy:423
# Contournr:23cx:920
# cy:494
# Contournr:1cx:721
# cy:703
# Contournr:2cx:983
# cy:684
# Contournr:3cx:994
# cy:641
# Contournr:4cx:555
# cy:639
# Contournr:5cx:525
# cy:647
# Contournr:6cx:933
# cy:642
# Contournr:7cx:782
# cy:584
# Contournr:8cx:789
# cy:583
# Contournr:10cx:557
# cy:614
# Contournr:11cx:970
# cy:587
# Contournr:12cx:700
# cy:553
# Contournr:13cx:896
# cy:538
# Contournr:14cx:951
# cy:530
# Contournr:15cx:978
# cy:553
# Contournr:16cx:567
# cy:512
# Contournr:17cx:849
# cy:527
# Contournr:18cx:976
# cy:512
# Contournr:19cx:726
# cy:554
# Contournr:20cx:536
# cy:503
# Contournr:21cx:628
# cy:568
# Contournr:22cx:992
# cy:424
# Contournr:23cx:915
# cy:494
# Contournr:1cx:716
# cy:703
# Contournr:2cx:979
# cy:682
# Contournr:3cx:988
# cy:640
# Contournr:4cx:550
# cy:639
# Contournr:5cx:522
# cy:649
# Contournr:6cx:931
# cy:641
# Contournr:7cx:778
# cy:585
# Contournr:8cx:784
# cy:583
# Contournr:9cx:555
# cy:616
# Contournr:10cx:967
# cy:586
# Contournr:11cx:695
# cy:553
# Contournr:12cx:890
# cy:539
# Contournr:13cx:946
# cy:530
# Contournr:14cx:975
# cy:551
# Contournr:15cx:998
# cy:519
# Contournr:16cx:562
# cy:512
# Contournr:17cx:844
# cy:527
# Contournr:18cx:971
# cy:513
# Contournr:19cx:721
# cy:554
# Contournr:20cx:533
# cy:504
# Contournr:21cx:624
# cy:568
# Contournr:22cx:990
# cy:424
# Contournr:23cx:909
# cy:494
# Contournr:1cx:711
# cy:704
# Contournr:2cx:974
# cy:681
# Contournr:4cx:545
# cy:639
# Contournr:5cx:519
# cy:651
# Contournr:6cx:928
# cy:640
# Contournr:7cx:779
# cy:583
# Contournr:8cx:552
# cy:618
# Contournr:11cx:911
# cy:567
# Contournr:12cx:965
# cy:584
# Contournr:13cx:690
# cy:553
# Contournr:14cx:995
# cy:547
# Contournr:15cx:885
# cy:539
# Contournr:16cx:941
# cy:530
# Contournr:17cx:973
# cy:549
# Contournr:18cx:557
# cy:513
# Contournr:19cx:839
# cy:527
# Contournr:20cx:965
# cy:513
# Contournr:21cx:716
# cy:554
# Contournr:23cx:531
# cy:506
# Contournr:24cx:620
# cy:568
# Objekt 9 im Scannbereich erkannt und gezählt!
# Contournr:25cx:988
# cy:425
# Contournr:26cx:904
# cy:494
# Contournr:1cx:706
# cy:704
# Contournr:2cx:968
# cy:682
# Contournr:3cx:977
# cy:640
# Contournr:4cx:540
# cy:639
# Contournr:5cx:516
# cy:652
# Contournr:6cx:926
# cy:638
# Contournr:7cx:774
# cy:583
# Contournr:8cx:550
# cy:619
# Contournr:9cx:887
# cy:572
# Contournr:10cx:686
# cy:553
# Contournr:11cx:963
# cy:582
# Contournr:12cx:881
# cy:539
# Contournr:13cx:936
# cy:530
# Contournr:14cx:970
# cy:547
# Contournr:15cx:553
# cy:513
# Contournr:16cx:998
# cy:510
# Contournr:17cx:834
# cy:527
# Contournr:18cx:960
# cy:513
# Contournr:19cx:528
# cy:506
# Contournr:20cx:711
# cy:555
# Contournr:21cx:616
# cy:568
# Contournr:22cx:985
# cy:425
# Contournr:23cx:899
# cy:494
# Contournr:1cx:998
# cy:736
# Contournr:2cx:998
# cy:727
# Contournr:3cx:701
# cy:704
# Contournr:4cx:964
# cy:681
# Contournr:5cx:974
# cy:640
# Contournr:6cx:514
# cy:653
# Contournr:8cx:924
# cy:637
# Contournr:9cx:547
# cy:621
# Contournr:10cx:769
# cy:584
# Contournr:11cx:882
# cy:572
# Contournr:12cx:900
# cy:567
# Contournr:13cx:681
# cy:553
# Contournr:14cx:963
# cy:580
# Contournr:15cx:875
# cy:539
# Contournr:16cx:931
# cy:530
# Contournr:18cx:548
# cy:512
# Contournr:19cx:968
# cy:545
# Contournr:20cx:829
# cy:527
# Contournr:22cx:955
# cy:513
# Contournr:23cx:525
# cy:507
# Contournr:24cx:706
# cy:554
# Contournr:25cx:611
# cy:569
# Contournr:26cx:983
# cy:426
# Contournr:27cx:894
# cy:494
# Contournr:1cx:996
# cy:733
# Contournr:2cx:997
# cy:717
# Contournr:3cx:697
# cy:704
# Contournr:4cx:958
# cy:681
# Contournr:5cx:968
# cy:640
# Contournr:6cx:512
# cy:653
# Contournr:7cx:922
# cy:635
# Contournr:8cx:545
# cy:622
# Contournr:9cx:764
# cy:583
# Contournr:11cx:876
# cy:572
# Contournr:12cx:676
# cy:553
# Contournr:13cx:963
# cy:577
# Contournr:14cx:870
# cy:539
# Contournr:15cx:927
# cy:530
# Contournr:16cx:543
# cy:513
# Contournr:17cx:824
# cy:527
# Contournr:18cx:965
# cy:543
# Contournr:19cx:998
# cy:501
# Contournr:20cx:950
# cy:513
# Contournr:21cx:522
# cy:509
# Contournr:22cx:701
# cy:555
# Contournr:23cx:607
# cy:569
# Contournr:24cx:980
# cy:426
# Contournr:25cx:889
# cy:494
# Contournr:1cx:993
# cy:733
# Contournr:2cx:989
# cy:727
# Contournr:3cx:995
# cy:717
# Contournr:4cx:692
# cy:704
# Contournr:5cx:953
# cy:682
# Contournr:6cx:962
# cy:640
# Contournr:7cx:510
# cy:653
# Contournr:8cx:543
# cy:624
# Contournr:9cx:759
# cy:584
# Contournr:10cx:872
# cy:573
# Contournr:11cx:671
# cy:553
# Contournr:12cx:939
# cy:608
# Contournr:13cx:865
# cy:539
# Contournr:14cx:922
# cy:530
# Contournr:16cx:538
# cy:513
# Contournr:17cx:819
# cy:527
# Contournr:18cx:962
# cy:541
# Contournr:19cx:945
# cy:513
# Contournr:20cx:518
# cy:510
# Contournr:21cx:697
# cy:555
# Contournr:22cx:603
# cy:569
# Contournr:23cx:978
# cy:427
# Contournr:24cx:884
# cy:495
# Contournr:1cx:988
# cy:734
# Contournr:2cx:985
# cy:727
# Contournr:3cx:993
# cy:716
# Contournr:4cx:687
# cy:704
# Contournr:5cx:949
# cy:681
# Contournr:7cx:509
# cy:651
# Contournr:8cx:540
# cy:626
# Contournr:9cx:754
# cy:583
# Contournr:11cx:867
# cy:573
# Contournr:14cx:667
# cy:553
# Contournr:15cx:939
# cy:606
# Contournr:16cx:860
# cy:539
# Contournr:17cx:917
# cy:530
# Contournr:18cx:533
# cy:513
# Contournr:19cx:813
# cy:528
# Contournr:20cx:960
# cy:539
# Contournr:22cx:940
# cy:513
# Contournr:23cx:515
# cy:510
# Contournr:24cx:691
# cy:555
# Contournr:25cx:598
# cy:569
# Contournr:26cx:976
# cy:428
# Contournr:27cx:879
# cy:495
# Contournr:1cx:983
# cy:734
# Contournr:2cx:979
# cy:728
# Contournr:3cx:991
# cy:714
# Contournr:4cx:682
# cy:704
# Contournr:5cx:943
# cy:682
# Contournr:6cx:951
# cy:640
# Contournr:7cx:507
# cy:649
# Contournr:8cx:538
# cy:627
# Contournr:9cx:749
# cy:584
# Contournr:12cx:662
# cy:553
# Contournr:13cx:855
# cy:539
# Contournr:14cx:936
# cy:604
# Contournr:15cx:912
# cy:531
# Contournr:16cx:528
# cy:513
# Contournr:17cx:808
# cy:528
# Contournr:18cx:935
# cy:513
# Contournr:19cx:957
# cy:537
# Contournr:20cx:512
# cy:511
# Contournr:21cx:687
# cy:555
# Contournr:22cx:594
# cy:569
# Contournr:23cx:974
# cy:428
# Contournr:24cx:874
# cy:495
# Contournr:1cx:978
# cy:734
# Contournr:2cx:975
# cy:728
# Contournr:3cx:677
# cy:704
# Contournr:4cx:989
# cy:711
# Contournr:5cx:939
# cy:682
# Contournr:6cx:947
# cy:640
# Contournr:7cx:505
# cy:648
# Contournr:9cx:536
# cy:629
# Contournr:10cx:744
# cy:584
# Contournr:12cx:657
# cy:553
# Contournr:13cx:851
# cy:540
# Contournr:14cx:934
# cy:602
# Contournr:15cx:907
# cy:531
# Contournr:16cx:524
# cy:513
# Contournr:17cx:803
# cy:528
# Contournr:18cx:930
# cy:513
# Contournr:19cx:954
# cy:535
# Contournr:20cx:510
# cy:511
# Contournr:21cx:681
# cy:555
# Contournr:22cx:590
# cy:569
# Contournr:23cx:972
# cy:429
# Contournr:24cx:869
# cy:495
# Contournr:2cx:974
# cy:733
# Contournr:3cx:970
# cy:727
# Contournr:5cx:672
# cy:704
# Contournr:6cx:987
# cy:708
# Contournr:7cx:933
# cy:681
# Contournr:8cx:942
# cy:640
# Contournr:9cx:504
# cy:647
# Contournr:10cx:533
# cy:630
# Contournr:11cx:739
# cy:584
# Contournr:12cx:851
# cy:573
# Contournr:14cx:652
# cy:554
# Contournr:15cx:845
# cy:539
# Contournr:16cx:902
# cy:531
# Contournr:17cx:932
# cy:601
# Contournr:19cx:519
# cy:513
# Contournr:20cx:798
# cy:528
# Contournr:21cx:925
# cy:513
# Contournr:22cx:507
# cy:511
# Contournr:23cx:952
# cy:533
# Contournr:24cx:677
# cy:555
# Contournr:25cx:585
# cy:570
# Contournr:26cx:969
# cy:430
# Contournr:27cx:864
# cy:495
# Contournr:1cx:998
# cy:883
# Contournr:3cx:997
# cy:863
# Contournr:4cx:998
# cy:846
# Contournr:5cx:992
# cy:730
# Contournr:6cx:969
# cy:734
# Contournr:7cx:964
# cy:728
# Contournr:9cx:998
# cy:726
# Contournr:10cx:668
# cy:704
# Contournr:11cx:985
# cy:706
# Contournr:12cx:928
# cy:683
# Contournr:13cx:935
# cy:640
# Contournr:14cx:502
# cy:644
# Contournr:15cx:531
# cy:632
# Contournr:16cx:734
# cy:584
# Contournr:17cx:996
# cy:576
# Contournr:20cx:647
# cy:554
# Contournr:21cx:840
# cy:540
# Contournr:22cx:897
# cy:531
# Contournr:23cx:930
# cy:600
# Contournr:24cx:514
# cy:513
# Contournr:25cx:793
# cy:528
# Contournr:26cx:920
# cy:513
# Contournr:27cx:505
# cy:511
# Contournr:28cx:948
# cy:532
# Contournr:30cx:672
# cy:555
# Contournr:31cx:998
# cy:469
# Contournr:32cx:581
# cy:570
# Contournr:33cx:967
# cy:431
# Contournr:34cx:859
# cy:495
# Contournr:1cx:996
# cy:865
# Contournr:3cx:998
# cy:829
# Contournr:4cx:964
# cy:734
# Contournr:5cx:960
# cy:728
# Contournr:6cx:989
# cy:726
# Contournr:7cx:996
# cy:725
# Contournr:8cx:663
# cy:704
# Contournr:9cx:983
# cy:702
# Contournr:11cx:923
# cy:682
# Contournr:13cx:932
# cy:640
# Contournr:14cx:529
# cy:633
# Contournr:15cx:997
# cy:593
# Contournr:17cx:729
# cy:584
# Contournr:18cx:996
# cy:571
# Contournr:19cx:642
# cy:554
# Contournr:20cx:835
# cy:540
# Contournr:21cx:893
# cy:531
# Contournr:22cx:928
# cy:599
# Contournr:24cx:509
# cy:513
# Contournr:25cx:788
# cy:528
# Contournr:26cx:915
# cy:513
# Contournr:28cx:503
# cy:507
# Contournr:29cx:944
# cy:532
# Contournr:30cx:992
# cy:483
# Contournr:31cx:667
# cy:555
# Contournr:32cx:996
# cy:470
# Contournr:33cx:577
# cy:570
# Contournr:34cx:965
# cy:431
# Contournr:35cx:854
# cy:495
# Contournr:1cx:994
# cy:856
# Contournr:2cx:998
# cy:802
# Contournr:3cx:998
# cy:793
# Contournr:4cx:959
# cy:734
# Contournr:5cx:954
# cy:728
# Contournr:7cx:982
# cy:726
# Contournr:8cx:993
# cy:727
# Contournr:9cx:658
# cy:704
# Contournr:10cx:981
# cy:700
# Contournr:11cx:918
# cy:682
# Contournr:12cx:925
# cy:640
# Contournr:13cx:526
# cy:635
# Contournr:14cx:724
# cy:584
# Contournr:16cx:835
# cy:573
# Contournr:17cx:995
# cy:581
# Contournr:18cx:638
# cy:554
# Contournr:19cx:830
# cy:540
# Contournr:20cx:888
# cy:531
# Contournr:21cx:500
# cy:524
# Contournr:22cx:925
# cy:598
# Contournr:23cx:505
# cy:513
# Contournr:24cx:783
# cy:528
# Contournr:25cx:910
# cy:513
# Contournr:26cx:503
# cy:494
# Contournr:27cx:939
# cy:532
# Contournr:28cx:988
# cy:484
# Contournr:29cx:662
# cy:555
# Contournr:30cx:994
# cy:472
# Contournr:31cx:573
# cy:570
# Contournr:32cx:963
# cy:432
# Contournr:33cx:849
# cy:495
# Contournr:1cx:992
# cy:844
# Contournr:2cx:997
# cy:767
# Contournr:3cx:950
# cy:728
# Contournr:5cx:992
# cy:733
# Contournr:6cx:653
# cy:704
# Contournr:7cx:978
# cy:697
# Contournr:8cx:912
# cy:682
# Contournr:9cx:920
# cy:640
# Contournr:10cx:524
# cy:636
# Contournr:11cx:719
# cy:584
# Contournr:14cx:992
# cy:584
# Contournr:15cx:633
# cy:554
# Contournr:17cx:825
# cy:540
# Contournr:18cx:883
# cy:531
# Contournr:19cx:922
# cy:597
# Contournr:20cx:500
# cy:513
# Contournr:21cx:778
# cy:528
# Contournr:22cx:905
# cy:513
# Contournr:23cx:501
# cy:492
# Contournr:25cx:934
# cy:532
# Contournr:26cx:657
# cy:555
# Contournr:27cx:992
# cy:474
# Contournr:28cx:569
# cy:570
# Contournr:29cx:960
# cy:433
# Contournr:30cx:844
# cy:495
# Contournr:1cx:990
# cy:836
# Contournr:4cx:991
# cy:738
# Contournr:5cx:648
# cy:705
# Contournr:6cx:975
# cy:694
# Contournr:7cx:908
# cy:682
# Contournr:9cx:915
# cy:639
# Contournr:10cx:522
# cy:638
# Contournr:11cx:714
# cy:584
# Contournr:13cx:988
# cy:586
# Contournr:14cx:628
# cy:554
# Contournr:15cx:820
# cy:540
# Contournr:16cx:878
# cy:531
# Contournr:17cx:773
# cy:528
# Contournr:18cx:900
# cy:514
# Contournr:19cx:928
# cy:532
# Contournr:20cx:652
# cy:556
# Contournr:21cx:926
# cy:583
# Contournr:22cx:566
# cy:571
# Contournr:23cx:958
# cy:433
# Contournr:24cx:839
# cy:496
# Contournr:2cx:944
# cy:734
# Contournr:3cx:940
# cy:728
# Contournr:4cx:968
# cy:726
# Contournr:5cx:988
# cy:815
# Contournr:6cx:643
# cy:705
# Contournr:7cx:901
# cy:682
# Contournr:8cx:908
# cy:639
# Contournr:9cx:974
# cy:690
# Contournr:10cx:519
# cy:639
# Contournr:12cx:997
# cy:594
# Contournr:13cx:709
# cy:584
# Contournr:14cx:982
# cy:586
# Contournr:15cx:623
# cy:554
# Contournr:16cx:815
# cy:540
# Contournr:17cx:873
# cy:532
# Contournr:18cx:768
# cy:529
# Contournr:19cx:895
# cy:514
# Contournr:20cx:923
# cy:532
# Contournr:21cx:972
# cy:484
# Contournr:22cx:647
# cy:556
# Contournr:23cx:924
# cy:580
# Contournr:24cx:563
# cy:572
# Contournr:25cx:955
# cy:434
# Contournr:26cx:833
# cy:495
# Contournr:2cx:985
# cy:810
# Contournr:3cx:638
# cy:705
# Contournr:4cx:897
# cy:682
# Contournr:5cx:905
# cy:639
# Contournr:6cx:971
# cy:687
# Contournr:7cx:517
# cy:640
# Contournr:8cx:995
# cy:593
# Contournr:9cx:704
# cy:585
# Contournr:12cx:977
# cy:586
# Contournr:13cx:618
# cy:554
# ...
# cy:485
# Contournr:23cx:521
# cy:480
# Contournr:24cx:530
# cy:476
# Contournr:25cx:539
# cy:470
# Contournr:26cx:632
# cy:471
# Contournr:27cx:549
# cy:466
# Contournr:28cx:557
# cy:461
# Contournr:29cx:567
# cy:457
# Contournr:31cx:629
# cy:456
# Contournr:33cx:627
# cy:442
# Contournr:34cx:624
# cy:427
# Contournr:35cx:614
# cy:400
# Contournr:36cx:520
# cy:414
# Contournr:2cx:511
# cy:618
# Contournr:3cx:528
# cy:605
# Contournr:4cx:537
# cy:594
# Contournr:5cx:548
# cy:585
# Contournr:6cx:559
# cy:576
# Contournr:8cx:570
# cy:566
# Contournr:9cx:580
# cy:556
# Contournr:10cx:591
# cy:547
# Contournr:12cx:641
# cy:542
# Contournr:13cx:601
# cy:537
# Contournr:14cx:612
# cy:528
# Contournr:15cx:505
# cy:528
# Contournr:16cx:639
# cy:527
# Contournr:17cx:622
# cy:519
# Objekt 135 im Scannbereich erkannt und gezählt!
# Contournr:18cx:635
# cy:507
# Contournr:19cx:648
# cy:499
# Contournr:20cx:500
# cy:489
# Contournr:21cx:507
# cy:485
# Contournr:22cx:630
# cy:485
# Contournr:23cx:516
# cy:480
# Contournr:24cx:526
# cy:476
# Contournr:25cx:535
# cy:471
# Contournr:26cx:627
# cy:471
# Contournr:27cx:544
# cy:466
# Contournr:28cx:553
# cy:461
# Contournr:29cx:563
# cy:457
# Contournr:30cx:625
# cy:456
# Contournr:31cx:572
# cy:452
# Contournr:32cx:622
# cy:442
# Objekt 136 im Scannbereich erkannt und gezählt!
# Contournr:33cx:619
# cy:427
# Contournr:34cx:609
# cy:400
# Contournr:35cx:516
# cy:413
# Contournr:1cx:505
# cy:709
# Contournr:2cx:508
# cy:616
# Contournr:3cx:523
# cy:605
# Contournr:4cx:533
# cy:595
# Contournr:5cx:544
# cy:585
# Contournr:6cx:554
# cy:576
# Contournr:7cx:565
# cy:566
# Contournr:8cx:575
# cy:557
# Contournr:9cx:586
# cy:547
# Contournr:10cx:637
# cy:542
# Contournr:11cx:596
# cy:538
# Contournr:12cx:607
# cy:528
# Contournr:13cx:500
# cy:528
# Contournr:14cx:634
# cy:527
# Contournr:15cx:617
# cy:519
# Contournr:16cx:630
# cy:508
# Contournr:17cx:643
# cy:499
# Contournr:18cx:502
# cy:485
# Contournr:19cx:625
# cy:485
# Contournr:20cx:511
# cy:481
# Contournr:21cx:521
# cy:476
# Contournr:22cx:530
# cy:471
# Contournr:23cx:623
# cy:471
# Contournr:24cx:540
# cy:466
# Contournr:25cx:548
# cy:461
# Contournr:26cx:557
# cy:457
# Contournr:27cx:620
# cy:456
# Objekt 137 im Scannbereich erkannt und gezählt!
# Contournr:28cx:567
# cy:452
# Contournr:29cx:617
# cy:442
# Contournr:30cx:615
# cy:427
# Contournr:31cx:605
# cy:400
# Contournr:32cx:515
# cy:411
# Contournr:2cx:505
# cy:614
# Contournr:3cx:518
# cy:605
# Contournr:4cx:528
# cy:595
# Contournr:5cx:539
# cy:585
# Contournr:6cx:550
# cy:576
# Contournr:7cx:560
# cy:566
# Contournr:8cx:570
# cy:557
# Contournr:9cx:582
# cy:547
# Contournr:11cx:632
# cy:542
# Contournr:12cx:592
# cy:538
# Contournr:13cx:602
# cy:528
# Contournr:14cx:629
# cy:528
# Contournr:15cx:613
# cy:519
# Contournr:16cx:626
# cy:508
# Contournr:17cx:639
# cy:499
# Contournr:18cx:500
# cy:485
# Contournr:19cx:621
# cy:485
# Objekt 138 im Scannbereich erkannt und gezählt!
# Contournr:20cx:507
# cy:481
# Contournr:21cx:516
# cy:476
# Contournr:22cx:526
# cy:471
# Contournr:23cx:618
# cy:471
# Contournr:24cx:534
# cy:466
# Contournr:25cx:544
# cy:461
# Contournr:26cx:553
# cy:457
# Contournr:28cx:615
# cy:456
# Contournr:29cx:613
# cy:442
# Contournr:30cx:500
# cy:434
# Contournr:31cx:610
# cy:428
# Contournr:32cx:600
# cy:400
# Contournr:33cx:512
# cy:409
# Contournr:1cx:503
# cy:611
# Contournr:2cx:514
# cy:605
# Contournr:3cx:524
# cy:595
# Contournr:4cx:535
# cy:585
# Contournr:5cx:545
# cy:576
# Contournr:6cx:555
# cy:567
# Contournr:7cx:566
# cy:557
# Contournr:8cx:577
# cy:547
# Contournr:9cx:628
# cy:542
# Contournr:10cx:587
# cy:538
# Contournr:11cx:598
# cy:528
# Contournr:12cx:625
# cy:528
# Contournr:13cx:608
# cy:519
# Contournr:14cx:621
# cy:508
# Objekt 139 im Scannbereich erkannt und gezählt!
# Contournr:15cx:634
# cy:499
# Contournr:16cx:616
# cy:485
# Contournr:17cx:502
# cy:481
# Contournr:18cx:512
# cy:476
# Contournr:19cx:521
# cy:471
# Contournr:20cx:613
# cy:471
# Contournr:21cx:530
# cy:466
# Contournr:22cx:539
# cy:461
# Contournr:23cx:549
# cy:457
# Contournr:24cx:611
# cy:457
# Contournr:25cx:558
# cy:452
# Contournr:26cx:608
# cy:443
# Contournr:27cx:605
# cy:428
# Contournr:28cx:595
# cy:400
# Contournr:29cx:511
# cy:409
# Contournr:2cx:501
# cy:610
# Contournr:3cx:509
# cy:606
# Contournr:4cx:519
# cy:595
# Contournr:5cx:530
# cy:585
# Contournr:6cx:540
# cy:576
# Contournr:8cx:551
# cy:566
# Contournr:9cx:561
# cy:557
# Contournr:10cx:572
# cy:547
# Contournr:12cx:623
# cy:542
# Contournr:13cx:582
# cy:538
# Contournr:14cx:593
# cy:528
# Contournr:15cx:620
# cy:528
# Objekt 140 im Scannbereich erkannt und gezählt!
# Contournr:16cx:607
# cy:523
# Contournr:17cx:602
# cy:518
# Contournr:18cx:616
# cy:508
# Contournr:19cx:629
# cy:499
# Contournr:20cx:611
# cy:485
# Contournr:22cx:507
# cy:476
# Contournr:23cx:516
# cy:471
# Contournr:24cx:609
# cy:471
# Contournr:25cx:525
# cy:466
# Contournr:26cx:534
# cy:462
# Contournr:27cx:543
# cy:457
# Contournr:28cx:606
# cy:456
# Contournr:29cx:554
# cy:452
# Contournr:31cx:603
# cy:443
# Contournr:33cx:601
# cy:428
# Contournr:34cx:590
# cy:400
# Contournr:35cx:509
# cy:408
# Contournr:2cx:504
# cy:606
# Contournr:3cx:514
# cy:595
# Contournr:4cx:525
# cy:585
# Contournr:5cx:536
# cy:576
# Contournr:7cx:546
# cy:566
# Contournr:8cx:556
# cy:557
# Contournr:9cx:568
# cy:547
# Contournr:11cx:618
# cy:542
# Contournr:12cx:578
# cy:538
# Contournr:13cx:588
# cy:528
# Contournr:14cx:616
# cy:528
# Contournr:15cx:598
# cy:519
# Contournr:16cx:612
# cy:508
# Contournr:17cx:624
# cy:499
# Contournr:18cx:607
# cy:486
# Contournr:19cx:502
# cy:476
# Contournr:20cx:511
# cy:471
# Contournr:21cx:604
# cy:471
# Contournr:22cx:521
# cy:467
# Contournr:23cx:530
# cy:462
# Contournr:24cx:539
# cy:457
# Contournr:25cx:548
# cy:452
# Contournr:26cx:601
# cy:457
# Contournr:27cx:599
# cy:443
# Contournr:28cx:596
# cy:428
# Contournr:29cx:507
# cy:408
# Contournr:30cx:586
# cy:401
# Contournr:1cx:501
# cy:606
# Contournr:2cx:509
# cy:595
# Contournr:3cx:521
# cy:585
# Contournr:4cx:531
# cy:576
# Contournr:5cx:542
# cy:567
# Contournr:6cx:552
# cy:557
# Contournr:7cx:563
# cy:547
# Contournr:9cx:614
# cy:542
# Contournr:10cx:573
# cy:538
# Contournr:11cx:583
# cy:528
# Contournr:12cx:611
# cy:528
# Contournr:13cx:598
# cy:523
# Contournr:14cx:593
# cy:519
# Contournr:15cx:606
# cy:508
# Contournr:16cx:620
# cy:499
# Objekt 141 im Scannbereich erkannt und gezählt!
# Contournr:17cx:602
# cy:485
# Contournr:18cx:500
# cy:476
# Contournr:19cx:507
# cy:471
# Contournr:20cx:600
# cy:471
# Contournr:21cx:517
# cy:467
# Contournr:22cx:525
# cy:462
# Contournr:23cx:535
# cy:457
# Contournr:24cx:544
# cy:452
# Contournr:25cx:597
# cy:457
# Contournr:27cx:594
# cy:443
# Contournr:28cx:591
# cy:428
# Contournr:29cx:505
# cy:407
# Contournr:30cx:581
# cy:401
# Contournr:1cx:505
# cy:595
# Contournr:2cx:516
# cy:585
# Contournr:3cx:526
# cy:576
# Contournr:4cx:537
# cy:567
# Contournr:5cx:547
# cy:557
# Contournr:6cx:558
# cy:548
# Contournr:7cx:609
# cy:543
# Contournr:8cx:568
# cy:538
# Contournr:9cx:578
# cy:529
# Contournr:10cx:607
# cy:528
# Contournr:11cx:593
# cy:523
# Contournr:12cx:588
# cy:519
# Contournr:13cx:602
# cy:508
# Contournr:14cx:615
# cy:499
# Contournr:15cx:598
# cy:486
# Contournr:16cx:502
# cy:471
# Contournr:17cx:595
# cy:472
# Contournr:18cx:512
# cy:467
# Contournr:19cx:521
# cy:462
# Contournr:20cx:530
# cy:457
# Contournr:21cx:539
# cy:452
# Contournr:22cx:592
# cy:457
# Contournr:23cx:590
# cy:443
# Contournr:24cx:587
# cy:428
# Contournr:25cx:503
# cy:406
# Contournr:26cx:576
# cy:401
# Contournr:1cx:501
# cy:595
# Contournr:2cx:511
# cy:585
# Contournr:3cx:522
# cy:577
# Contournr:4cx:532
# cy:567
# Contournr:5cx:542
# cy:557
# Contournr:6cx:553
# cy:548
# Contournr:7cx:561
# cy:543
# Contournr:8cx:605
# cy:542
# Contournr:9cx:563
# cy:538
# Contournr:10cx:598
# cy:532
# Contournr:11cx:574
# cy:529
# Contournr:12cx:603
# cy:527
# Contournr:13cx:584
# cy:519
# Contournr:14cx:597
# cy:508
# Contournr:15cx:610
# cy:499
# Contournr:16cx:593
# cy:486
# Contournr:17cx:500
# cy:471
# Contournr:18cx:590
# cy:472
# Contournr:19cx:507
# cy:467
# Contournr:20cx:516
# cy:462
# Contournr:21cx:526
# cy:457
# Contournr:22cx:587
# cy:457
# Contournr:23cx:535
# cy:453
# Contournr:24cx:585
# cy:443
# Contournr:25cx:582
# cy:428
# Contournr:26cx:502
# cy:404
# Contournr:27cx:571
# cy:401
# Contournr:2cx:507
# cy:586
# Contournr:3cx:517
# cy:577
# Contournr:5cx:528
# cy:567
# Contournr:6cx:537
# cy:558
# Contournr:7cx:549
# cy:548
# Contournr:9cx:600
# cy:542
# Contournr:10cx:558
# cy:538
# Contournr:11cx:593
# cy:532
# Contournr:12cx:569
# cy:529
# Contournr:13cx:598
# cy:527
# Contournr:14cx:584
# cy:524
# Contournr:15cx:579
# cy:519
# Contournr:16cx:592
# cy:508
# Contournr:17cx:605
# cy:500
# Contournr:18cx:588
# cy:486
# Contournr:19cx:586
# cy:472
# Contournr:20cx:503
# cy:467
# Contournr:21cx:512
# cy:462
# Contournr:22cx:521
# cy:458
# Contournr:23cx:583
# cy:457
# Contournr:24cx:530
# cy:453
# Contournr:25cx:580
# cy:443
# Contournr:26cx:578
# cy:428
# Contournr:27cx:500
# cy:404
# Contournr:28cx:567
# cy:401
# Contournr:1cx:503
# cy:586
# Contournr:2cx:512
# cy:577
# Contournr:3cx:523
# cy:567
# Contournr:4cx:533
# cy:558
# Contournr:5cx:543
# cy:548
# Contournr:6cx:595
# cy:543
# Contournr:7cx:554
# cy:539
# Contournr:8cx:588
# cy:532
# Contournr:9cx:564
# cy:529
# Contournr:10cx:594
# cy:527
# Contournr:11cx:574
# cy:519
# Contournr:12cx:594
# cy:510
# Contournr:13cx:586
# cy:508
# Contournr:14cx:601
# cy:499
# Contournr:15cx:584
# cy:486
# Contournr:16cx:581
# cy:472
# Contournr:17cx:500
# cy:467
# Contournr:18cx:507
# cy:462
# Contournr:19cx:516
# cy:457
# Contournr:20cx:578
# cy:457
# Contournr:21cx:526
# cy:453
# Contournr:23cx:576
# cy:443
# Contournr:24cx:573
# cy:428
# Contournr:25cx:562
# cy:401
# Contournr:1cx:500
# cy:585
# Contournr:2cx:507
# cy:577
# Contournr:3cx:518
# cy:567
# Contournr:4cx:528
# cy:558
# Contournr:5cx:539
# cy:548
# Contournr:6cx:591
# cy:543
# Contournr:7cx:549
# cy:539
# Contournr:8cx:584
# cy:532
# Contournr:9cx:559
# cy:529
# Contournr:10cx:589
# cy:528
# Contournr:11cx:570
# cy:519
# Contournr:12cx:582
# cy:508
# Contournr:13cx:596
# cy:500
# Contournr:14cx:579
# cy:486
# Contournr:15cx:576
# cy:472
# Contournr:16cx:502
# cy:462
# Contournr:17cx:511
# cy:458
# Contournr:18cx:573
# cy:457
# Contournr:19cx:521
# cy:453
# Contournr:20cx:571
# cy:443
# Contournr:21cx:568
# cy:428
# Contournr:22cx:557
# cy:401
# Contournr:1cx:503
# cy:577
# Contournr:2cx:514
# cy:567
# Contournr:3cx:523
# cy:558
# Contournr:4cx:534
# cy:548
# Contournr:5cx:586
# cy:543
# Contournr:6cx:544
# cy:539
# Contournr:7cx:554
# cy:530
# Contournr:8cx:584
# cy:528
# Contournr:10cx:564
# cy:519
# Contournr:11cx:578
# cy:509
# Contournr:12cx:591
# cy:500
# Contournr:13cx:575
# cy:486
# Contournr:14cx:572
# cy:472
# Contournr:15cx:500
# cy:462
# Contournr:16cx:507
# cy:458
# Contournr:17cx:569
# cy:457
# Contournr:18cx:516
# cy:453
# Contournr:20cx:566
# cy:443
# Contournr:21cx:564
# cy:429
# Contournr:22cx:552
# cy:401
# Contournr:1cx:500
# cy:577
# Contournr:3cx:509
# cy:567
# Contournr:4cx:519
# cy:558
# Contournr:5cx:530
# cy:548
# Contournr:6cx:581
# cy:543
# Contournr:7cx:540
# cy:539
# Contournr:8cx:574
# cy:532
# Contournr:9cx:550
# cy:530
# Contournr:10cx:580
# cy:528
# Contournr:11cx:560
# cy:520
# Contournr:12cx:573
# cy:509
# Contournr:13cx:586
# cy:500
# Contournr:14cx:570
# cy:486
# Contournr:15cx:567
# cy:472
# Contournr:16cx:502
# cy:458
# Contournr:17cx:565
# cy:457
# Contournr:18cx:512
# cy:453
# Contournr:19cx:522
# cy:448
# Contournr:20cx:562
# cy:443
# Contournr:21cx:559
# cy:429
# Contournr:22cx:548
# cy:401
# Contournr:2cx:504
# cy:567
# Contournr:3cx:514
# cy:558
# Contournr:4cx:525
# cy:548
# Contournr:6cx:577
# cy:543
# Contournr:7cx:535
# cy:539
# Contournr:8cx:570
# cy:532
# Contournr:9cx:545
# cy:529
# Contournr:10cx:575
# cy:528
# Contournr:11cx:560
# cy:524
# Contournr:12cx:555
# cy:519
# Contournr:13cx:568
# cy:509
# Contournr:14cx:581
# cy:500
# Contournr:15cx:565
# cy:486
# Contournr:16cx:563
# cy:472
# Contournr:17cx:500
# cy:458
# Contournr:18cx:560
# cy:458
# Contournr:19cx:507
# cy:453
# Contournr:20cx:517
# cy:449
# Contournr:21cx:557
# cy:443
# Contournr:22cx:554
# cy:429
# Contournr:23cx:543
# cy:402
# Contournr:1cx:501
# cy:567
# Contournr:2cx:509
# cy:558
# Contournr:3cx:520
# cy:548
# Contournr:4cx:572
# cy:543
# Contournr:5cx:530
# cy:539
# Contournr:6cx:565
# cy:532
# Contournr:7cx:540
# cy:530
# Contournr:8cx:571
# cy:528
# Contournr:9cx:550
# cy:520
# Contournr:10cx:563
# cy:509
# Contournr:11cx:577
# cy:500
# Contournr:12cx:561
# cy:486
# Contournr:13cx:558
# cy:472
# Contournr:14cx:555
# cy:458
# Contournr:15cx:503
# cy:453
# Contournr:18cx:552
# cy:444
# Contournr:19cx:550
# cy:429
# Contournr:20cx:538
# cy:402
# Contournr:1cx:505
# cy:558
# Contournr:2cx:515
# cy:549
# Contournr:3cx:568
# cy:543
# Contournr:4cx:525
# cy:540
# Contournr:5cx:560
# cy:533
# Contournr:6cx:535
# cy:530
# Contournr:7cx:566
# cy:528
# Contournr:8cx:546
# cy:520
# Contournr:9cx:558
# cy:509
# Contournr:10cx:572
# cy:500
# Contournr:11cx:556
# cy:486
# Contournr:12cx:553
# cy:472
# Contournr:13cx:551
# cy:458
# Contournr:14cx:500
# cy:453
# Contournr:16cx:548
# cy:444
# Contournr:17cx:545
# cy:429
# Contournr:18cx:533
# cy:402
# Contournr:1cx:502
# cy:558
# Contournr:2cx:511
# cy:549
# Contournr:3cx:563
# cy:543
# Contournr:4cx:521
# cy:540
# Contournr:5cx:556
# cy:533
# Contournr:6cx:531
# cy:530
# Contournr:7cx:561
# cy:528
# Contournr:8cx:546
# cy:524
# Contournr:9cx:541
# cy:520
# Contournr:10cx:554
# cy:509
# Contournr:11cx:567
# cy:500
# Contournr:12cx:551
# cy:486
# Contournr:13cx:549
# cy:472
# Contournr:14cx:546
# cy:458
# Contournr:15cx:504
# cy:449
# Contournr:16cx:543
# cy:444
# Contournr:17cx:540
# cy:429
# Contournr:18cx:529
# cy:402
# Contournr:2cx:506
# cy:549
# Contournr:4cx:559
# cy:543
# Contournr:5cx:516
# cy:540
# Contournr:7cx:526
# cy:530
# Contournr:8cx:557
# cy:528
# Contournr:9cx:536
# cy:520
# Contournr:10cx:549
# cy:509
# Contournr:11cx:563
# cy:500
# Contournr:12cx:547
# cy:486
# Contournr:13cx:544
# cy:472
# Contournr:14cx:541
# cy:458
# Contournr:16cx:539
# cy:444
# Contournr:17cx:536
# cy:429
# Contournr:18cx:524
# cy:402
# Contournr:1cx:502
# cy:549
# Contournr:3cx:554
# cy:544
# Contournr:4cx:511
# cy:540
# Contournr:7cx:522
# cy:530
# Contournr:8cx:552
# cy:528
# Contournr:9cx:536
# cy:524
# Contournr:10cx:531
# cy:520
# Contournr:11cx:544
# cy:509
# Contournr:12cx:558
# cy:501
# Contournr:13cx:542
# cy:486
# Contournr:14cx:540
# cy:472
# Contournr:15cx:537
# cy:458
# Contournr:16cx:534
# cy:444
# Contournr:17cx:531
# cy:429
# Contournr:18cx:519
# cy:402
# Contournr:1cx:500
# cy:548
# Contournr:2cx:550
# cy:544
# Contournr:3cx:507
# cy:540
# Contournr:4cx:517
# cy:531
# Contournr:5cx:548
# cy:528
# Contournr:6cx:531
# cy:524
# Contournr:7cx:527
# cy:520
# Contournr:8cx:540
# cy:510
# Contournr:9cx:553
# cy:500
# Contournr:10cx:538
# cy:487
# Contournr:11cx:535
# cy:472
# Contournr:12cx:532
# cy:458
# Contournr:13cx:530
# cy:444
# Contournr:14cx:527
# cy:429
# Contournr:15cx:516
# cy:402
# Contournr:1cx:545
# cy:543
# Contournr:2cx:503
# cy:540
# Contournr:4cx:512
# cy:531
# Contournr:5cx:544
# cy:528
# Contournr:7cx:522
# cy:520
# Contournr:8cx:535
# cy:510
# Contournr:9cx:549
# cy:501
# Contournr:10cx:533
# cy:487
# Contournr:11cx:530
# cy:473
# Contournr:12cx:528
# cy:458
# Contournr:13cx:525
# cy:444
# Contournr:14cx:522
# cy:429
# Contournr:15cx:513
# cy:403
# Contournr:1cx:541
# cy:544
# Contournr:2cx:500
# cy:539
# Contournr:4cx:508
# cy:531
# Contournr:5cx:539
# cy:528
# Contournr:7cx:517
# cy:520
# Contournr:8cx:530
# cy:510
# Contournr:9cx:544
# cy:501
# Contournr:10cx:529
# cy:487
# Contournr:11cx:526
# cy:473
# Contournr:12cx:523
# cy:458
# Contournr:13cx:521
# cy:444
# Contournr:14cx:518
# cy:430
# Contournr:15cx:515
# cy:414
# Contournr:16cx:508
# cy:397
# Contournr:2cx:536
# cy:544
# Contournr:3cx:503
# cy:531
# Contournr:4cx:535
# cy:528
# Contournr:6cx:513
# cy:520
# Contournr:7cx:526
# cy:510
# Contournr:8cx:539
# cy:501
# Contournr:9cx:524
# cy:487
# Contournr:10cx:521
# cy:473
# Contournr:11cx:519
# cy:458
# Contournr:12cx:516
# cy:444
# Contournr:13cx:513
# cy:430
# Contournr:14cx:510
# cy:414
# Contournr:15cx:505
# cy:397
# Contournr:1cx:532
# cy:544
# Contournr:2cx:501
# cy:530
# Contournr:3cx:530
# cy:528
# Contournr:4cx:513
# cy:525
# Contournr:5cx:508
# cy:520
# Contournr:6cx:521
# cy:510
# Contournr:7cx:535
# cy:501
# Contournr:8cx:520
# cy:487
# Contournr:9cx:517
# cy:473
# Contournr:10cx:514
# cy:459
# Contournr:11cx:511
# cy:444
# Contournr:12cx:509
# cy:430
# Contournr:13cx:506
# cy:414
# Contournr:14cx:503
# cy:397
# Contournr:1cx:527
# cy:544
# Contournr:2cx:526
# cy:528
# Contournr:3cx:508
# cy:525
# Contournr:4cx:503
# cy:521
# Contournr:5cx:517
# cy:510
# Contournr:6cx:530
# cy:501
# Contournr:7cx:515
# cy:487
# Contournr:8cx:512
# cy:473
# Contournr:9cx:510
# cy:459
# Contournr:10cx:507
# cy:444
# Contournr:11cx:504
# cy:430
# Contournr:12cx:503
# cy:414
# Contournr:13cx:501
# cy:398
# Contournr:1cx:523
# cy:544
# Contournr:2cx:521
# cy:528
# Contournr:3cx:504
# cy:525
# Contournr:4cx:501
# cy:521
# Contournr:6cx:512
# cy:510
# Contournr:7cx:525
# cy:501
# Contournr:8cx:511
# cy:487
# Contournr:9cx:508
# cy:473
# Contournr:10cx:505
# cy:459
# Contournr:11cx:504
# cy:444
# Contournr:12cx:502
# cy:429
# Contournr:13cx:501
# cy:414
# Contournr:1cx:518
# cy:544
# Contournr:3cx:517
# cy:529
# Contournr:5cx:508
# cy:510
# Contournr:6cx:521
# cy:501
# Contournr:7cx:506
# cy:487
# Contournr:8cx:504
# cy:473
# Contournr:9cx:503
# cy:458
# Contournr:10cx:501
# cy:444
# Contournr:11cx:500
# cy:430
# Contournr:1cx:514
# cy:544
# Contournr:2cx:512
# cy:529
# Contournr:3cx:503
# cy:510
# Contournr:4cx:516
# cy:501
# Contournr:5cx:503
# cy:487
# Contournr:6cx:502
# cy:472
# Contournr:7cx:500
# cy:458
# Contournr:1cx:509
# cy:544
# Contournr:2cx:507
# cy:529
# Contournr:3cx:503
# cy:510
# Contournr:4cx:511
# cy:501
# Contournr:5cx:501
# cy:487
# Contournr:6cx:500
# cy:474
# Contournr:1cx:505
# cy:545
# Contournr:2cx:503
# cy:529
# Contournr:3cx:501
# cy:511
# Contournr:4cx:507
# cy:501
# Contournr:1cx:500
# cy:545
# Contournr:2cx:500
# cy:530
# Contournr:3cx:502
# cy:501
# Contournr:1cx:500
# cy:498

# %%
print(Result)
# Out:
# [24, 32, 141]
